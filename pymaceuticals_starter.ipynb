# %% [markdown]
# ## Observations and Insights

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# %%
# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# %%
# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# %%
# Combine the data into a single dataset
mouse_df = pd.merge(mouse_metadata, study_results, on="Mouse ID")
mouse_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# 2              35.014271                 1
# 3              34.223992                 1
# 4              32.997729                 1
# ...                  ...               ...
# 1888           63.145652                 2
# 1889           65.841013                 3
# 1890           69.176246                 4
# 1891           70.314904                 4
# 1892           73.867845                 4
#
# [1893 rows x 8 columns]

# %%
# Checking the number of mice.
unique = len(pd.unique(mouse_df["Mouse ID"]))
print("The number of mice based on their ID: "+ str(unique))
# Out:
# The number of mice based on their ID: 249

# %%
#get the duplicate mice by id number that shows up for Mouse ID and timepoint

duplicate_df = mouse_df[mouse_df.duplicated(['Mouse ID', 'Timepoint'])]
duplicate_df.shape
# Out:
# (5, 8)

# %%
mouse_df.iloc[909:918]
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 909     g989     Propriva  Female          21          26          0
# 910     g989     Propriva  Female          21          26          5
# 911     g989     Propriva  Female          21          26          5
# 912     g989     Propriva  Female          21          26         10
# 913     g989     Propriva  Female          21          26         10
# 914     g989     Propriva  Female          21          26         15
# 915     g989     Propriva  Female          21          26         15
# 916     g989     Propriva  Female          21          26         20
# 917     g989     Propriva  Female          21          26         20
#
#      Tumor Volume (mm3)  Metastatic Sites
# 909           45.000000                 0
# 910           48.786801                 0
# 911           47.570392                 0
# 912           51.745156                 0
# 913           49.880528                 0
# 914           51.325852                 1
# 915           53.442020                 0
# 916           55.326122                 1
# 917           54.657650                 1

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
mouse_df.loc[mouse_df['Mouse ID']!='g989']

clean_df = mouse_df.loc[mouse_df['Mouse ID']!='g989']
clean_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# 2              35.014271                 1
# 3              34.223992                 1
# 4              32.997729                 1
# ...                  ...               ...
# 1888           63.145652                 2
# 1889           65.841013                 3
# 1890           69.176246                 4
# 1891           70.314904                 4
# 1892           73.867845                 4
#
# [1880 rows x 8 columns]

# %%
mouse_df['Mouse ID']
# Out:
# 0       k403
# 1       k403
# 2       k403
# 3       k403
# 4       k403
#         ...
# 1888    z969
# 1889    z969
# 1890    z969
# 1891    z969
# 1892    z969
# Name: Mouse ID, Length: 1893, dtype: object

# %%
# Checking the number of mice in the clean DataFrame.
unique_clean = len(pd.unique(clean_df["Mouse ID"]))
print("The final number of mice: "+ str(unique_clean))
# Out:
# The final number of mice: 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
clean_df.groupby('Drug Regimen').agg(
    {
        "Tumor Volume (mm3)": ["mean", "median", "var", "std", "sem"],
    }
)
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %%
# Using the aggregation method, produce the same summary statistics in a single line

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of measurements taken on each drug regimen using pandas.

# %%
x_axis = np.arange(len(clean_df))
tick_locations = [value for value in x_axis]
plt.figure(figsize=(20,3))
plt.bar(x_axis, clean_df["Drug Regimen"], color='r', alpha=0.5, align="center")
plt.xticks(tick_locations, clean_df["Timepoint"], rotation="vertical")
# Out:
# ([<matplotlib.axis.XTick at 0x20141c44948>,
#   <matplotlib.axis.XTick at 0x20141c53c48>,
#   <matplotlib.axis.XTick at 0x20141c53208>,
#   <matplotlib.axis.XTick at 0x2014346e608>,
#   <matplotlib.axis.XTick at 0x2014346ee48>,
#   <matplotlib.axis.XTick at 0x20143475788>,
#   <matplotlib.axis.XTick at 0x20143475a08>,
#   <matplotlib.axis.XTick at 0x20143479088>,
#   <matplotlib.axis.XTick at 0x20143479b88>,
#   <matplotlib.axis.XTick at 0x2014347d6c8>,
#   <matplotlib.axis.XTick at 0x20143481348>,
#   <matplotlib.axis.XTick at 0x20143481f08>,
#   <matplotlib.axis.XTick at 0x20143484b08>,
#   <matplotlib.axis.XTick at 0x20143487708>,
#   <matplotlib.axis.XTick at 0x20143484308>,
#   <matplotlib.axis.XTick at 0x2014348b088>,
#   <matplotlib.axis.XTick at 0x2014348bc08>,
#   <matplotlib.axis.XTick at 0x2014348d688>,
#   <matplotlib.axis.XTick at 0x20143490148>,
#   <matplotlib.axis.XTick at 0x20143490d08>,
#   <matplotlib.axis.XTick at 0x20143493908>,
#   <matplotlib.axis.XTick at 0x20143497508>,
#   <matplotlib.axis.XTick at 0x2014349b088>,
#   <matplotlib.axis.XTick at 0x20143493088>,
#   <matplotlib.axis.XTick at 0x2014349bbc8>,
#   <matplotlib.axis.XTick at 0x2014349f588>,
#   <matplotlib.axis.XTick at 0x2014349ffc8>,
#   <matplotlib.axis.XTick at 0x201434a0a48>,
#   <matplotlib.axis.XTick at 0x201434a5648>,
#   <matplotlib.axis.XTick at 0x201434a9248>,
#   <matplotlib.axis.XTick at 0x201434a9e08>,
#   <matplotlib.axis.XTick at 0x201434ada08>,
#   <matplotlib.axis.XTick at 0x201434a5b88>,
#   <matplotlib.axis.XTick at 0x201434b0508>,
#   <matplotlib.axis.XTick at 0x201434b0e88>,
#   <matplotlib.axis.XTick at 0x201434b2908>,
#   <matplotlib.axis.XTick at 0x201434b6388>,
#   <matplotlib.axis.XTick at 0x201434b6f48>,
#   <matplotlib.axis.XTick at 0x201434b9b48>,
#   <matplotlib.axis.XTick at 0x201434bc748>,
#   <matplotlib.axis.XTick at 0x201434c0348>,
#   <matplotlib.axis.XTick at 0x201434b92c8>,
#   <matplotlib.axis.XTick at 0x201434c0e08>,
#   <matplotlib.axis.XTick at 0x201434c37c8>,
#   <matplotlib.axis.XTick at 0x201434c5248>,
#   <matplotlib.axis.XTick at 0x201434c5c88>,
#   <matplotlib.axis.XTick at 0x201434c9888>,
#   <matplotlib.axis.XTick at 0x201434cd488>,
#   <matplotlib.axis.XTick at 0x201434d2048>,
#   <matplotlib.axis.XTick at 0x201434d2c48>,
#   <matplotlib.axis.XTick at 0x201434c9c48>,
#   <matplotlib.axis.XTick at 0x201434d5748>,
#   <matplotlib.axis.XTick at 0x201434d8088>,
#   <matplotlib.axis.XTick at 0x201434d8b48>,
#   <matplotlib.axis.XTick at 0x201434db5c8>,
#   <matplotlib.axis.XTick at 0x201434df1c8>,
#   <matplotlib.axis.XTick at 0x201434dfd88>,
#   <matplotlib.axis.XTick at 0x201434e1988>,
#   <matplotlib.axis.XTick at 0x201434e5588>,
#   <matplotlib.axis.XTick at 0x201434e1a88>,
#   <matplotlib.axis.XTick at 0x201434c9988>,
#   <matplotlib.axis.XTick at 0x201434e9a08>,
#   <matplotlib.axis.XTick at 0x201434eb488>,
#   <matplotlib.axis.XTick at 0x201434ebec8>,
#   <matplotlib.axis.XTick at 0x201434efac8>,
#   <matplotlib.axis.XTick at 0x201434f16c8>,
#   <matplotlib.axis.XTick at 0x201434f52c8>,
#   <matplotlib.axis.XTick at 0x201434f5e88>,
#   <matplotlib.axis.XTick at 0x201434efe88>,
#   <matplotlib.axis.XTick at 0x201434f9988>,
#   <matplotlib.axis.XTick at 0x201434fc348>,
#   <matplotlib.axis.XTick at 0x201434fcd88>,
#   <matplotlib.axis.XTick at 0x201434fe808>,
#   <matplotlib.axis.XTick at 0x20143501408>,
#   <matplotlib.axis.XTick at 0x20143501fc8>,
#   <matplotlib.axis.XTick at 0x20143507bc8>,
#   <matplotlib.axis.XTick at 0x201435097c8>,
#   <matplotlib.axis.XTick at 0x20143507108>,
#   <matplotlib.axis.XTick at 0x2014350d2c8>,
#   <matplotlib.axis.XTick at 0x2014350dc48>,
#   <matplotlib.axis.XTick at 0x2014350f6c8>,
#   <matplotlib.axis.XTick at 0x20143513148>,
#   <matplotlib.axis.XTick at 0x20143513d08>,
#   <matplotlib.axis.XTick at 0x20143516908>,
#   <matplotlib.axis.XTick at 0x2014351a508>,
#   <matplotlib.axis.XTick at 0x2014351d088>,
#   <matplotlib.axis.XTick at 0x20143516088>,
#   <matplotlib.axis.XTick at 0x2014351dbc8>,
#   <matplotlib.axis.XTick at 0x20143521588>,
#   <matplotlib.axis.XTick at 0x20143521fc8>,
#   <matplotlib.axis.XTick at 0x20143524a48>,
#   <matplotlib.axis.XTick at 0x20143528648>,
#   <matplotlib.axis.XTick at 0x2014352c248>,
#   <matplotlib.axis.XTick at 0x2014352ce08>,
#   <matplotlib.axis.XTick at 0x2014352fa08>,
#   <matplotlib.axis.XTick at 0x20143528b88>,
#   <matplotlib.axis.XTick at 0x20143532508>,
#   <matplotlib.axis.XTick at 0x20143532e88>,
#   <matplotlib.axis.XTick at 0x20143535908>,
#   <matplotlib.axis.XTick at 0x20143538388>,
#   <matplotlib.axis.XTick at 0x20143538f48>,
#   <matplotlib.axis.XTick at 0x2014353cb48>,
#   <matplotlib.axis.XTick at 0x20143540748>,
#   <matplotlib.axis.XTick at 0x20143544348>,
#   <matplotlib.axis.XTick at 0x2014353c2c8>,
#   <matplotlib.axis.XTick at 0x20143544e08>,
#   <matplotlib.axis.XTick at 0x201435477c8>,
#   <matplotlib.axis.XTick at 0x20143549248>,
#   <matplotlib.axis.XTick at 0x20143549c88>,
#   <matplotlib.axis.XTick at 0x2014354d888>,
#   <matplotlib.axis.XTick at 0x20143550488>,
#   <matplotlib.axis.XTick at 0x20143554048>,
#   <matplotlib.axis.XTick at 0x20143554c48>,
#   <matplotlib.axis.XTick at 0x2014354dc48>,
#   <matplotlib.axis.XTick at 0x2014352f948>,
#   <matplotlib.axis.XTick at 0x201434adb08>,
#   <matplotlib.axis.XTick at 0x20143557a88>,
#   <matplotlib.axis.XTick at 0x20143559508>,
#   <matplotlib.axis.XTick at 0x20143559f48>,
#   <matplotlib.axis.XTick at 0x2014355c9c8>,
#   <matplotlib.axis.XTick at 0x2014355e448>,
#   <matplotlib.axis.XTick at 0x2014355ee88>,
#   <matplotlib.axis.XTick at 0x20143562908>,
#   <matplotlib.axis.XTick at 0x201435098c8>,
#   <matplotlib.axis.XTick at 0x20143565048>,
#   <matplotlib.axis.XTick at 0x20143565ac8>,
#   <matplotlib.axis.XTick at 0x20143567548>,
#   <matplotlib.axis.XTick at 0x20143567f88>,
#   <matplotlib.axis.XTick at 0x2014356bb48>,
#   <matplotlib.axis.XTick at 0x2014356e748>,
#   <matplotlib.axis.XTick at 0x20143571348>,
#   <matplotlib.axis.XTick at 0x20143571f08>,
#   <matplotlib.axis.XTick at 0x2014356b2c8>,
#   <matplotlib.axis.XTick at 0x201435788c8>,
#   <matplotlib.axis.XTick at 0x2014357a348>,
#   <matplotlib.axis.XTick at 0x2014357ad88>,
#   <matplotlib.axis.XTick at 0x2014357d808>,
#   <matplotlib.axis.XTick at 0x201435813c8>,
#   <matplotlib.axis.XTick at 0x20143581f88>,
#   <matplotlib.axis.XTick at 0x20143584b88>,
#   <matplotlib.axis.XTick at 0x20143587788>,
#   <matplotlib.axis.XTick at 0x20143584148>,
#   <matplotlib.axis.XTick at 0x2014358b188>,
#   <matplotlib.axis.XTick at 0x2014358bc08>,
#   <matplotlib.axis.XTick at 0x2014358d688>,
#   <matplotlib.axis.XTick at 0x20143591088>,
#   <matplotlib.axis.XTick at 0x20143591cc8>,
#   <matplotlib.axis.XTick at 0x201435948c8>,
#   <matplotlib.axis.XTick at 0x201435974c8>,
#   <matplotlib.axis.XTick at 0x2014359c048>,
#   <matplotlib.axis.XTick at 0x20143594048>,
#   <matplotlib.axis.XTick at 0x2014359cb88>,
#   <matplotlib.axis.XTick at 0x2014359f548>,
#   <matplotlib.axis.XTick at 0x2014359ff88>,
#   <matplotlib.axis.XTick at 0x2014359da08>,
#   <matplotlib.axis.XTick at 0x201435a4608>,
#   <matplotlib.axis.XTick at 0x201435a8208>,
#   <matplotlib.axis.XTick at 0x201435a8dc8>,
#   <matplotlib.axis.XTick at 0x201435ad9c8>,
#   <matplotlib.axis.XTick at 0x201435a4b48>,
#   <matplotlib.axis.XTick at 0x201435b04c8>,
#   <matplotlib.axis.XTick at 0x201435b0e48>,
#   <matplotlib.axis.XTick at 0x201435b28c8>,
#   <matplotlib.axis.XTick at 0x201435b6348>,
#   <matplotlib.axis.XTick at 0x201435b6f08>,
#   <matplotlib.axis.XTick at 0x201435b9b08>,
#   <matplotlib.axis.XTick at 0x201435bd708>,
#   <matplotlib.axis.XTick at 0x201435c0308>,
#   <matplotlib.axis.XTick at 0x201435b9288>,
#   <matplotlib.axis.XTick at 0x201435c0dc8>,
#   <matplotlib.axis.XTick at 0x201435c3788>,
#   <matplotlib.axis.XTick at 0x201435c6208>,
#   <matplotlib.axis.XTick at 0x201435c6c48>,
#   <matplotlib.axis.XTick at 0x201435c9848>,
#   <matplotlib.axis.XTick at 0x201435cd448>,
#   <matplotlib.axis.XTick at 0x201435cdfc8>,
#   <matplotlib.axis.XTick at 0x201435d2c08>,
#   <matplotlib.axis.XTick at 0x201435c9c08>,
#   <matplotlib.axis.XTick at 0x201435d4708>,
#   <matplotlib.axis.XTick at 0x201435d7048>,
#   <matplotlib.axis.XTick at 0x201435d7b08>,
#   <matplotlib.axis.XTick at 0x201435db588>,
#   <matplotlib.axis.XTick at 0x201435de188>,
#   <matplotlib.axis.XTick at 0x201435ded48>,
#   <matplotlib.axis.XTick at 0x201435e2948>,
#   <matplotlib.axis.XTick at 0x201435e6548>,
#   <matplotlib.axis.XTick at 0x201435e22c8>,
#   <matplotlib.axis.XTick at 0x201435d4908>,
#   <matplotlib.axis.XTick at 0x201435e99c8>,
#   <matplotlib.axis.XTick at 0x201435eb448>,
#   <matplotlib.axis.XTick at 0x201435ebe88>,
#   <matplotlib.axis.XTick at 0x201435efa88>,
#   <matplotlib.axis.XTick at 0x201435f2688>,
#   <matplotlib.axis.XTick at 0x201435f5288>,
#   <matplotlib.axis.XTick at 0x201435f5e48>,
#   <matplotlib.axis.XTick at 0x201435efe48>,
#   <matplotlib.axis.XTick at 0x201435f9948>,
#   <matplotlib.axis.XTick at 0x201435fc308>,
#   <matplotlib.axis.XTick at 0x201435fcd48>,
#   <matplotlib.axis.XTick at 0x201435fe7c8>,
#   <matplotlib.axis.XTick at 0x201436023c8>,
#   <matplotlib.axis.XTick at 0x20143602f88>,
#   <matplotlib.axis.XTick at 0x20143606b88>,
#   <matplotlib.axis.XTick at 0x20143608788>,
#   <matplotlib.axis.XTick at 0x20143606148>,
#   <matplotlib.axis.XTick at 0x2014360c288>,
#   <matplotlib.axis.XTick at 0x2014360cc08>,
#   <matplotlib.axis.XTick at 0x2014360f688>,
#   <matplotlib.axis.XTick at 0x20143612088>,
#   <matplotlib.axis.XTick at 0x20143612cc8>,
#   <matplotlib.axis.XTick at 0x201436178c8>,
#   <matplotlib.axis.XTick at 0x2014361a4c8>,
#   <matplotlib.axis.XTick at 0x2014361f048>,
#   <matplotlib.axis.XTick at 0x20143617048>,
#   <matplotlib.axis.XTick at 0x2014361fb88>,
#   <matplotlib.axis.XTick at 0x20143622548>,
#   <matplotlib.axis.XTick at 0x20143622f88>,
#   <matplotlib.axis.XTick at 0x20143623a08>,
#   <matplotlib.axis.XTick at 0x20143628608>,
#   <matplotlib.axis.XTick at 0x2014362c208>,
#   <matplotlib.axis.XTick at 0x2014362cdc8>,
#   <matplotlib.axis.XTick at 0x2014362f9c8>,
#   <matplotlib.axis.XTick at 0x20143628b48>,
#   <matplotlib.axis.XTick at 0x20143608888>,
#   <matplotlib.axis.XTick at 0x20143587cc8>,
#   <matplotlib.axis.XTick at 0x20143632888>,
#   <matplotlib.axis.XTick at 0x20143635308>,
#   <matplotlib.axis.XTick at 0x20143635d48>,
#   <matplotlib.axis.XTick at 0x201436377c8>,
#   <matplotlib.axis.XTick at 0x2014363a248>,
#   <matplotlib.axis.XTick at 0x2014363ac88>,
#   <matplotlib.axis.XTick at 0x2014363d708>,
#   <matplotlib.axis.XTick at 0x201435f5fc8>,
#   <matplotlib.axis.XTick at 0x2014363de88>,
#   <matplotlib.axis.XTick at 0x20143641908>,
#   <matplotlib.axis.XTick at 0x20143643388>,
#   <matplotlib.axis.XTick at 0x20143643dc8>,
#   <matplotlib.axis.XTick at 0x20143647988>,
#   <matplotlib.axis.XTick at 0x2014364b588>,
#   <matplotlib.axis.XTick at 0x2014364e188>,
#   <matplotlib.axis.XTick at 0x2014364ed48>,
#   <matplotlib.axis.XTick at 0x20143647188>,
#   <matplotlib.axis.XTick at 0x20143650708>,
#   <matplotlib.axis.XTick at 0x20143653188>,
#   <matplotlib.axis.XTick at 0x20143653bc8>,
#   <matplotlib.axis.XTick at 0x20143657648>,
#   <matplotlib.axis.XTick at 0x2014365b208>,
#   <matplotlib.axis.XTick at 0x2014365bdc8>,
#   <matplotlib.axis.XTick at 0x2014365f9c8>,
#   <matplotlib.axis.XTick at 0x201436625c8>,
#   <matplotlib.axis.XTick at 0x2014365f348>,
#   <matplotlib.axis.XTick at 0x20143647108>,
#   <matplotlib.axis.XTick at 0x20143666a48>,
#   <matplotlib.axis.XTick at 0x201436674c8>,
#   <matplotlib.axis.XTick at 0x20143667f08>,
#   <matplotlib.axis.XTick at 0x2014366bb08>,
#   <matplotlib.axis.XTick at 0x2014366e708>,
#   <matplotlib.axis.XTick at 0x20143672308>,
#   <matplotlib.axis.XTick at 0x20143672ec8>,
#   <matplotlib.axis.XTick at 0x2014366bec8>,
#   <matplotlib.axis.XTick at 0x201436769c8>,
#   <matplotlib.axis.XTick at 0x20143679388>,
#   <matplotlib.axis.XTick at 0x20143679dc8>,
#   <matplotlib.axis.XTick at 0x2014367c848>,
#   <matplotlib.axis.XTick at 0x20143680448>,
#   <matplotlib.axis.XTick at 0x20143680fc8>,
#   <matplotlib.axis.XTick at 0x20143684c08>,
#   <matplotlib.axis.XTick at 0x20143687808>,
#   <matplotlib.axis.XTick at 0x20143684148>,
#   <matplotlib.axis.XTick at 0x2014368b308>,
#   <matplotlib.axis.XTick at 0x2014368bc88>,
#   <matplotlib.axis.XTick at 0x2014368d708>,
#   <matplotlib.axis.XTick at 0x20143691188>,
#   <matplotlib.axis.XTick at 0x20143691d48>,
#   <matplotlib.axis.XTick at 0x20143694948>,
#   <matplotlib.axis.XTick at 0x20143697548>,
#   <matplotlib.axis.XTick at 0x2014369b148>,
#   <matplotlib.axis.XTick at 0x201436940c8>,
#   <matplotlib.axis.XTick at 0x2014369bc08>,
#   <matplotlib.axis.XTick at 0x2014369f5c8>,
#   <matplotlib.axis.XTick at 0x2014369ffc8>,
#   <matplotlib.axis.XTick at 0x201436a2a88>,
#   <matplotlib.axis.XTick at 0x201436a4688>,
#   <matplotlib.axis.XTick at 0x201436a8288>,
#   <matplotlib.axis.XTick at 0x201436a8e48>,
#   <matplotlib.axis.XTick at 0x201436aca48>,
#   <matplotlib.axis.XTick at 0x201436a4a48>,
#   <matplotlib.axis.XTick at 0x201436b0548>,
#   <matplotlib.axis.XTick at 0x201436b0ec8>,
#   <matplotlib.axis.XTick at 0x201436b2948>,
#   <matplotlib.axis.XTick at 0x201436b53c8>,
#   <matplotlib.axis.XTick at 0x201436b5f88>,
#   <matplotlib.axis.XTick at 0x201436b9b88>,
#   <matplotlib.axis.XTick at 0x201436bc788>,
#   <matplotlib.axis.XTick at 0x201436c0388>,
#   <matplotlib.axis.XTick at 0x201436b9308>,
#   <matplotlib.axis.XTick at 0x201436c0e48>,
#   <matplotlib.axis.XTick at 0x201436c4808>,
#   <matplotlib.axis.XTick at 0x201436c6288>,
#   <matplotlib.axis.XTick at 0x201436c6cc8>,
#   <matplotlib.axis.XTick at 0x201436ca8c8>,
#   <matplotlib.axis.XTick at 0x201436ce4c8>,
#   <matplotlib.axis.XTick at 0x201436d1048>,
#   <matplotlib.axis.XTick at 0x201436d1c88>,
#   <matplotlib.axis.XTick at 0x201436cac88>,
#   <matplotlib.axis.XTick at 0x201436d4788>,
#   <matplotlib.axis.XTick at 0x201436d7148>,
#   <matplotlib.axis.XTick at 0x201436d7b88>,
#   <matplotlib.axis.XTick at 0x201436d9608>,
#   <matplotlib.axis.XTick at 0x201436de208>,
#   <matplotlib.axis.XTick at 0x201436dedc8>,
#   <matplotlib.axis.XTick at 0x201436e19c8>,
#   <matplotlib.axis.XTick at 0x201436e55c8>,
#   <matplotlib.axis.XTick at 0x201436e1908>,
#   <matplotlib.axis.XTick at 0x201436ce408>,
#   <matplotlib.axis.XTick at 0x201436e9a48>,
#   <matplotlib.axis.XTick at 0x201436ea4c8>,
#   <matplotlib.axis.XTick at 0x201436eaf08>,
#   <matplotlib.axis.XTick at 0x201436eeb08>,
#   <matplotlib.axis.XTick at 0x201436f1708>,
#   <matplotlib.axis.XTick at 0x201436f6308>,
#   <matplotlib.axis.XTick at 0x201436f6ec8>,
#   <matplotlib.axis.XTick at 0x201436eeec8>,
#   <matplotlib.axis.XTick at 0x201436f99c8>,
#   <matplotlib.axis.XTick at 0x201436fc388>,
#   <matplotlib.axis.XTick at 0x201436fcdc8>,
#   <matplotlib.axis.XTick at 0x201436fe848>,
#   <matplotlib.axis.XTick at 0x20143702448>,
#   <matplotlib.axis.XTick at 0x20143702fc8>,
#   <matplotlib.axis.XTick at 0x20143706c08>,
#   <matplotlib.axis.XTick at 0x20143709808>,
#   <matplotlib.axis.XTick at 0x20143706148>,
#   <matplotlib.axis.XTick at 0x201436f6e08>,
#   <matplotlib.axis.XTick at 0x20143676248>,
#   <matplotlib.axis.XTick at 0x2014370c6c8>,
#   <matplotlib.axis.XTick at 0x2014370e148>,
#   <matplotlib.axis.XTick at 0x2014370eb88>,
#   <matplotlib.axis.XTick at 0x20143711608>,
#   <matplotlib.axis.XTick at 0x20143714048>,
#   <matplotlib.axis.XTick at 0x20143714ac8>,
#   <matplotlib.axis.XTick at 0x20143719548>,
#   <matplotlib.axis.XTick at 0x20143662b08>,
#   <matplotlib.axis.XTick at 0x20143719cc8>,
#   <matplotlib.axis.XTick at 0x2014371a748>,
#   <matplotlib.axis.XTick at 0x2014371f1c8>,
#   <matplotlib.axis.XTick at 0x2014371fc08>,
#   <matplotlib.axis.XTick at 0x201437227c8>,
#   <matplotlib.axis.XTick at 0x201437263c8>,
#   <matplotlib.axis.XTick at 0x20143726f88>,
#   <matplotlib.axis.XTick at 0x2014372ab88>,
#   <matplotlib.axis.XTick at 0x2014371ff88>,
#   <matplotlib.axis.XTick at 0x2014372d548>,
#   <matplotlib.axis.XTick at 0x2014372df88>,
#   <matplotlib.axis.XTick at 0x2014372fa08>,
#   <matplotlib.axis.XTick at 0x20143733488>,
#   <matplotlib.axis.XTick at 0x20143733fc8>,
#   <matplotlib.axis.XTick at 0x20143737c08>,
#   <matplotlib.axis.XTick at 0x2014373a808>,
#   <matplotlib.axis.XTick at 0x2014373e408>,
#   <matplotlib.axis.XTick at 0x20143737388>,
#   <matplotlib.axis.XTick at 0x2014373edc8>,
#   <matplotlib.axis.XTick at 0x20143741888>,
#   <matplotlib.axis.XTick at 0x20143743308>,
#   <matplotlib.axis.XTick at 0x20143743d48>,
#   <matplotlib.axis.XTick at 0x20143747948>,
#   <matplotlib.axis.XTick at 0x2014374b548>,
#   <matplotlib.axis.XTick at 0x2014374e148>,
#   <matplotlib.axis.XTick at 0x2014374ed08>,
#   <matplotlib.axis.XTick at 0x20143747d08>,
#   <matplotlib.axis.XTick at 0x20143752808>,
#   <matplotlib.axis.XTick at 0x201437541c8>,
#   <matplotlib.axis.XTick at 0x20143754c08>,
#   <matplotlib.axis.XTick at 0x20143756688>,
#   <matplotlib.axis.XTick at 0x2014375b288>,
#   <matplotlib.axis.XTick at 0x2014375be48>,
#   <matplotlib.axis.XTick at 0x2014375ea48>,
#   <matplotlib.axis.XTick at 0x20143761648>,
#   <matplotlib.axis.XTick at 0x2014375e1c8>,
#   <matplotlib.axis.XTick at 0x20143765148>,
#   <matplotlib.axis.XTick at 0x20143765ac8>,
#   <matplotlib.axis.XTick at 0x20143767548>,
#   <matplotlib.axis.XTick at 0x20143767f88>,
#   <matplotlib.axis.XTick at 0x2014376ab88>,
#   <matplotlib.axis.XTick at 0x2014376e788>,
#   <matplotlib.axis.XTick at 0x20143773388>,
#   <matplotlib.axis.XTick at 0x20143773f48>,
#   <matplotlib.axis.XTick at 0x2014376af48>,
#   <matplotlib.axis.XTick at 0x20143777a48>,
#   <matplotlib.axis.XTick at 0x20143779408>,
#   <matplotlib.axis.XTick at 0x20143779e48>,
#   <matplotlib.axis.XTick at 0x2014377d8c8>,
#   <matplotlib.axis.XTick at 0x201437804c8>,
#   <matplotlib.axis.XTick at 0x20143784048>,
#   <matplotlib.axis.XTick at 0x20143784c88>,
#   <matplotlib.axis.XTick at 0x20143786888>,
#   <matplotlib.axis.XTick at 0x20143780fc8>,
#   <matplotlib.axis.XTick at 0x2014378a388>,
#   <matplotlib.axis.XTick at 0x2014378ad08>,
#   <matplotlib.axis.XTick at 0x2014378c788>,
#   <matplotlib.axis.XTick at 0x20143790208>,
#   <matplotlib.axis.XTick at 0x20143790dc8>,
#   <matplotlib.axis.XTick at 0x201437939c8>,
#   <matplotlib.axis.XTick at 0x201437965c8>,
#   <matplotlib.axis.XTick at 0x2014379b1c8>,
#   <matplotlib.axis.XTick at 0x20143793148>,
#   <matplotlib.axis.XTick at 0x2014379bc88>,
#   <matplotlib.axis.XTick at 0x2014379f648>,
#   <matplotlib.axis.XTick at 0x201437a1048>,
#   <matplotlib.axis.XTick at 0x201437a1b08>,
#   <matplotlib.axis.XTick at 0x201437a4708>,
#   <matplotlib.axis.XTick at 0x201437a9308>,
#   <matplotlib.axis.XTick at 0x201437a9ec8>,
#   <matplotlib.axis.XTick at 0x201437adac8>,
#   <matplotlib.axis.XTick at 0x201437a4ac8>,
#   <matplotlib.axis.XTick at 0x201437b05c8>,
#   <matplotlib.axis.XTick at 0x201437b0f48>,
#   <matplotlib.axis.XTick at 0x201437b29c8>,
#   <matplotlib.axis.XTick at 0x201437b5448>,
#   <matplotlib.axis.XTick at 0x201437b5fc8>,
#   <matplotlib.axis.XTick at 0x201437bac08>,
#   <matplotlib.axis.XTick at 0x201437bc808>,
#   <matplotlib.axis.XTick at 0x201437c0408>,
#   <matplotlib.axis.XTick at 0x201437ba388>,
#   <matplotlib.axis.XTick at 0x201437c0ec8>,
#   <matplotlib.axis.XTick at 0x201437c3888>,
#   <matplotlib.axis.XTick at 0x201437c5308>,
#   <matplotlib.axis.XTick at 0x201437c5d48>,
#   <matplotlib.axis.XTick at 0x201437c9948>,
#   <matplotlib.axis.XTick at 0x201437cd548>,
#   <matplotlib.axis.XTick at 0x201437d0148>,
#   <matplotlib.axis.XTick at 0x201437d0d08>,
#   <matplotlib.axis.XTick at 0x201437c9d08>,
#   <matplotlib.axis.XTick at 0x201437d5808>,
#   <matplotlib.axis.XTick at 0x201437d81c8>,
#   <matplotlib.axis.XTick at 0x201437d8c08>,
#   <matplotlib.axis.XTick at 0x201437da688>,
#   <matplotlib.axis.XTick at 0x201437de288>,
#   <matplotlib.axis.XTick at 0x201437dee48>,
#   <matplotlib.axis.XTick at 0x201437e1a48>,
#   <matplotlib.axis.XTick at 0x201437e5648>,
#   <matplotlib.axis.XTick at 0x201437e11c8>,
#   <matplotlib.axis.XTick at 0x201437d5108>,
#   <matplotlib.axis.XTick at 0x201437617c8>,
#   <matplotlib.axis.XTick at 0x201437e9508>,
#   <matplotlib.axis.XTick at 0x201437e9f48>,
#   <matplotlib.axis.XTick at 0x201437ea9c8>,
#   <matplotlib.axis.XTick at 0x201437ec448>,
#   <matplotlib.axis.XTick at 0x201437ece88>,
#   <matplotlib.axis.XTick at 0x201437ef908>,
#   <matplotlib.axis.XTick at 0x201437f4388>,
#   <matplotlib.axis.XTick at 0x2014373e348>,
#   <matplotlib.axis.XTick at 0x201437f4b08>,
#   <matplotlib.axis.XTick at 0x201437f6588>,
#   <matplotlib.axis.XTick at 0x201437f6fc8>,
#   <matplotlib.axis.XTick at 0x201437f9a48>,
#   <matplotlib.axis.XTick at 0x201437fc608>,
#   <matplotlib.axis.XTick at 0x20143800208>,
#   <matplotlib.axis.XTick at 0x20143800dc8>,
#   <matplotlib.axis.XTick at 0x201438039c8>,
#   <matplotlib.axis.XTick at 0x201437f9d48>,
#   <matplotlib.axis.XTick at 0x20143806388>,
#   <matplotlib.axis.XTick at 0x20143806dc8>,
#   <matplotlib.axis.XTick at 0x20143808848>,
#   <matplotlib.axis.XTick at 0x2014380c2c8>,
#   <matplotlib.axis.XTick at 0x2014380ce48>,
#   <matplotlib.axis.XTick at 0x20143810a48>,
#   <matplotlib.axis.XTick at 0x20143815648>,
#   <matplotlib.axis.XTick at 0x20143818248>,
#   <matplotlib.axis.XTick at 0x201438101c8>,
#   <matplotlib.axis.XTick at 0x20143818c08>,
#   <matplotlib.axis.XTick at 0x2014381c6c8>,
#   <matplotlib.axis.XTick at 0x20143820148>,
#   <matplotlib.axis.XTick at 0x20143820b88>,
#   <matplotlib.axis.XTick at 0x20143823788>,
#   <matplotlib.axis.XTick at 0x20143826388>,
#   <matplotlib.axis.XTick at 0x20143826f48>,
#   <matplotlib.axis.XTick at 0x2014382ab48>,
#   <matplotlib.axis.XTick at 0x20143823b48>,
#   <matplotlib.axis.XTick at 0x2014382d648>,
#   <matplotlib.axis.XTick at 0x2014382dfc8>,
#   <matplotlib.axis.XTick at 0x2014382fa48>,
#   <matplotlib.axis.XTick at 0x201438334c8>,
#   <matplotlib.axis.XTick at 0x20143836048>,
#   <matplotlib.axis.XTick at 0x20143836c88>,
#   <matplotlib.axis.XTick at 0x20143839888>,
#   <matplotlib.axis.XTick at 0x2014383d488>,
#   <matplotlib.axis.XTick at 0x20143839dc8>,
#   <matplotlib.axis.XTick at 0x20143820408>,
#   <matplotlib.axis.XTick at 0x20143840908>,
#   <matplotlib.axis.XTick at 0x20143842388>,
#   <matplotlib.axis.XTick at 0x20143842dc8>,
#   <matplotlib.axis.XTick at 0x201438479c8>,
#   <matplotlib.axis.XTick at 0x2014384b5c8>,
#   <matplotlib.axis.XTick at 0x2014384e1c8>,
#   <matplotlib.axis.XTick at 0x2014384ed88>,
#   <matplotlib.axis.XTick at 0x20143847d88>,
#   <matplotlib.axis.XTick at 0x20143851888>,
#   <matplotlib.axis.XTick at 0x20143854248>,
#   <matplotlib.axis.XTick at 0x20143854c88>,
#   <matplotlib.axis.XTick at 0x20143856708>,
#   <matplotlib.axis.XTick at 0x2014385b308>,
#   <matplotlib.axis.XTick at 0x2014385bec8>,
#   <matplotlib.axis.XTick at 0x2014385eac8>,
#   <matplotlib.axis.XTick at 0x201438616c8>,
#   <matplotlib.axis.XTick at 0x2014385e088>,
#   <matplotlib.axis.XTick at 0x20143865048>,
#   <matplotlib.axis.XTick at 0x20143865b48>,
#   <matplotlib.axis.XTick at 0x201438675c8>,
#   <matplotlib.axis.XTick at 0x20143867fc8>,
#   <matplotlib.axis.XTick at 0x2014386bc08>,
#   <matplotlib.axis.XTick at 0x2014386e808>,
#   <matplotlib.axis.XTick at 0x20143872408>,
#   <matplotlib.axis.XTick at 0x20143872fc8>,
#   <matplotlib.axis.XTick at 0x2014386bf48>,
#   <matplotlib.axis.XTick at 0x20143877ac8>,
#   <matplotlib.axis.XTick at 0x20143879488>,
#   <matplotlib.axis.XTick at 0x20143879ec8>,
#   <matplotlib.axis.XTick at 0x2014387c948>,
#   <matplotlib.axis.XTick at 0x20143880548>,
#   <matplotlib.axis.XTick at 0x20143884148>,
#   <matplotlib.axis.XTick at 0x20143884d08>,
#   <matplotlib.axis.XTick at 0x20143887908>,
#   <matplotlib.axis.XTick at 0x20143884088>,
#   <matplotlib.axis.XTick at 0x2014388b408>,
#   <matplotlib.axis.XTick at 0x2014388bd88>,
#   <matplotlib.axis.XTick at 0x2014388c808>,
#   <matplotlib.axis.XTick at 0x20143890288>,
#   <matplotlib.axis.XTick at 0x20143890e48>,
#   <matplotlib.axis.XTick at 0x20143893a48>,
#   <matplotlib.axis.XTick at 0x20143898648>,
#   <matplotlib.axis.XTick at 0x2014389b248>,
#   <matplotlib.axis.XTick at 0x201438931c8>,
#   <matplotlib.axis.XTick at 0x2014389bd08>,
#   <matplotlib.axis.XTick at 0x2014389e6c8>,
#   <matplotlib.axis.XTick at 0x201438a1148>,
#   <matplotlib.axis.XTick at 0x201438a1b88>,
#   <matplotlib.axis.XTick at 0x201438a4788>,
#   <matplotlib.axis.XTick at 0x201438a7388>,
#   <matplotlib.axis.XTick at 0x201438a7f48>,
#   <matplotlib.axis.XTick at 0x201438abb48>,
#   <matplotlib.axis.XTick at 0x201438a4b48>,
#   <matplotlib.axis.XTick at 0x201438b0648>,
#   <matplotlib.axis.XTick at 0x201438b0fc8>,
#   <matplotlib.axis.XTick at 0x201438b2a48>,
#   <matplotlib.axis.XTick at 0x201438b64c8>,
#   <matplotlib.axis.XTick at 0x201438b9048>,
#   <matplotlib.axis.XTick at 0x201438b9c88>,
#   <matplotlib.axis.XTick at 0x201438bc888>,
#   <matplotlib.axis.XTick at 0x201438c0488>,
#   <matplotlib.axis.XTick at 0x201438bcdc8>,
#   <matplotlib.axis.XTick at 0x201438b0f08>,
#   <matplotlib.axis.XTick at 0x2014384ecc8>,
#   <matplotlib.axis.XTick at 0x201438c3348>,
#   <matplotlib.axis.XTick at 0x201438c3d88>,
#   <matplotlib.axis.XTick at 0x201438c5808>,
#   <matplotlib.axis.XTick at 0x201438c8288>,
#   <matplotlib.axis.XTick at 0x201438c8cc8>,
#   <matplotlib.axis.XTick at 0x201438cc748>,
#   <matplotlib.axis.XTick at 0x201438cf1c8>,
#   <matplotlib.axis.XTick at 0x201438c3288>,
#   <matplotlib.axis.XTick at 0x201438cf948>,
#   <matplotlib.axis.XTick at 0x201438d13c8>,
#   <matplotlib.axis.XTick at 0x201438d1e08>,
#   <matplotlib.axis.XTick at 0x201438d5888>,
#   <matplotlib.axis.XTick at 0x201438d8448>,
#   <matplotlib.axis.XTick at 0x201438d8fc8>,
#   <matplotlib.axis.XTick at 0x201438dcc08>,
#   <matplotlib.axis.XTick at 0x201438df808>,
#   <matplotlib.axis.XTick at 0x201438d1d48>,
#   <matplotlib.axis.XTick at 0x201438e21c8>,
#   <matplotlib.axis.XTick at 0x201438e2c08>,
#   <matplotlib.axis.XTick at 0x201438e4688>,
#   <matplotlib.axis.XTick at 0x201438e9088>,
#   <matplotlib.axis.XTick at 0x201438e9c88>,
#   <matplotlib.axis.XTick at 0x201438ec888>,
#   <matplotlib.axis.XTick at 0x201438ef488>,
#   <matplotlib.axis.XTick at 0x201438f4048>,
#   <matplotlib.axis.XTick at 0x201438e9fc8>,
#   <matplotlib.axis.XTick at 0x201438f4a48>,
#   <matplotlib.axis.XTick at 0x201438f6508>,
#   <matplotlib.axis.XTick at 0x201438f6f48>,
#   <matplotlib.axis.XTick at 0x201438f99c8>,
#   <matplotlib.axis.XTick at 0x201438fd5c8>,
#   <matplotlib.axis.XTick at 0x201439001c8>,
#   <matplotlib.axis.XTick at 0x20143900d88>,
#   <matplotlib.axis.XTick at 0x20143903988>,
#   <matplotlib.axis.XTick at 0x201438fdb08>,
#   <matplotlib.axis.XTick at 0x20143907488>,
#   <matplotlib.axis.XTick at 0x20143907e08>,
#   <matplotlib.axis.XTick at 0x20143909888>,
#   <matplotlib.axis.XTick at 0x2014390c308>,
#   <matplotlib.axis.XTick at 0x2014390cec8>,
#   <matplotlib.axis.XTick at 0x2014390fac8>,
#   <matplotlib.axis.XTick at 0x201439146c8>,
#   <matplotlib.axis.XTick at 0x201439112c8>,
#   <matplotlib.axis.XTick at 0x2014390f248>,
#   <matplotlib.axis.XTick at 0x20143911d88>,
#   <matplotlib.axis.XTick at 0x2014391c748>,
#   <matplotlib.axis.XTick at 0x2014391f1c8>,
#   <matplotlib.axis.XTick at 0x2014391fc08>,
#   <matplotlib.axis.XTick at 0x20143921808>,
#   <matplotlib.axis.XTick at 0x20143926408>,
#   <matplotlib.axis.XTick at 0x20143926fc8>,
#   <matplotlib.axis.XTick at 0x2014392abc8>,
#   <matplotlib.axis.XTick at 0x20143921bc8>,
#   <matplotlib.axis.XTick at 0x2014392d6c8>,
#   <matplotlib.axis.XTick at 0x2014392f048>,
#   <matplotlib.axis.XTick at 0x2014392fac8>,
#   <matplotlib.axis.XTick at 0x20143932548>,
#   <matplotlib.axis.XTick at 0x20143936148>,
#   <matplotlib.axis.XTick at 0x20143936d08>,
#   <matplotlib.axis.XTick at 0x2014393a908>,
#   <matplotlib.axis.XTick at 0x2014393d508>,
#   <matplotlib.axis.XTick at 0x2014393ac48>,
#   <matplotlib.axis.XTick at 0x2014391f488>,
#   <matplotlib.axis.XTick at 0x20143941988>,
#   <matplotlib.axis.XTick at 0x20143942408>,
#   <matplotlib.axis.XTick at 0x20143942e48>,
#   <matplotlib.axis.XTick at 0x20143947a48>,
#   <matplotlib.axis.XTick at 0x2014394a648>,
#   <matplotlib.axis.XTick at 0x2014394e248>,
#   <matplotlib.axis.XTick at 0x2014394ee08>,
#   <matplotlib.axis.XTick at 0x20143947e08>,
#   <matplotlib.axis.XTick at 0x20143950908>,
#   <matplotlib.axis.XTick at 0x201439532c8>,
#   <matplotlib.axis.XTick at 0x20143953d08>,
#   <matplotlib.axis.XTick at 0x20143957788>,
#   <matplotlib.axis.XTick at 0x2014395a388>,
#   <matplotlib.axis.XTick at 0x2014395af48>,
#   <matplotlib.axis.XTick at 0x2014395eb48>,
#   <matplotlib.axis.XTick at 0x20143962748>,
#   <matplotlib.axis.XTick at 0x2014395e108>,
#   <matplotlib.axis.XTick at 0x201439650c8>,
#   <matplotlib.axis.XTick at 0x20143965bc8>,
#   <matplotlib.axis.XTick at 0x20143967648>,
#   <matplotlib.axis.XTick at 0x2014396b048>,
#   <matplotlib.axis.XTick at 0x2014396bc88>,
#   <matplotlib.axis.XTick at 0x2014396e888>,
#   <matplotlib.axis.XTick at 0x20143972488>,
#   <matplotlib.axis.XTick at 0x20143976048>,
#   <matplotlib.axis.XTick at 0x2014396bfc8>,
#   <matplotlib.axis.XTick at 0x20143976b48>,
#   <matplotlib.axis.XTick at 0x20143979508>,
#   <matplotlib.axis.XTick at 0x20143979f48>,
#   <matplotlib.axis.XTick at 0x2014397b9c8>,
#   <matplotlib.axis.XTick at 0x201439805c8>,
#   <matplotlib.axis.XTick at 0x201439831c8>,
#   <matplotlib.axis.XTick at 0x20143983d88>,
#   <matplotlib.axis.XTick at 0x20143986988>,
#   <matplotlib.axis.XTick at 0x20143980b08>,
#   <matplotlib.axis.XTick at 0x2014398a488>,
#   <matplotlib.axis.XTick at 0x2014398ae08>,
#   <matplotlib.axis.XTick at 0x2014398c888>,
#   <matplotlib.axis.XTick at 0x2014398f308>,
#   <matplotlib.axis.XTick at 0x2014398fec8>,
#   <matplotlib.axis.XTick at 0x20143994ac8>,
#   <matplotlib.axis.XTick at 0x201439986c8>,
#   <matplotlib.axis.XTick at 0x201439952c8>,
#   <matplotlib.axis.XTick at 0x20143994248>,
#   <matplotlib.axis.XTick at 0x20143962c88>,
#   <matplotlib.axis.XTick at 0x201438dcb48>,
#   <matplotlib.axis.XTick at 0x2014399d188>,
#   <matplotlib.axis.XTick at 0x2014399dbc8>,
#   <matplotlib.axis.XTick at 0x201439a0648>,
#   <matplotlib.axis.XTick at 0x201439a3048>,
#   <matplotlib.axis.XTick at 0x201439a3b08>,
#   <matplotlib.axis.XTick at 0x201439a6588>,
#   <matplotlib.axis.XTick at 0x201439a6fc8>,
#   <matplotlib.axis.XTick at 0x2014399d2c8>,
#   <matplotlib.axis.XTick at 0x201439aa788>,
#   <matplotlib.axis.XTick at 0x201439ad208>,
#   <matplotlib.axis.XTick at 0x201439adc48>,
#   <matplotlib.axis.XTick at 0x201439af6c8>,
#   <matplotlib.axis.XTick at 0x201439b4288>,
#   <matplotlib.axis.XTick at 0x201439b4e48>,
#   <matplotlib.axis.XTick at 0x201439b7a48>,
#   <matplotlib.axis.XTick at 0x201439ba648>,
#   <matplotlib.axis.XTick at 0x201439adcc8>,
#   <matplotlib.axis.XTick at 0x201439bafc8>,
#   <matplotlib.axis.XTick at 0x201439bea48>,
#   <matplotlib.axis.XTick at 0x201439c14c8>,
#   <matplotlib.axis.XTick at 0x201439c1f08>,
#   <matplotlib.axis.XTick at 0x201439c4ac8>,
#   <matplotlib.axis.XTick at 0x201439c66c8>,
#   <matplotlib.axis.XTick at 0x201439cb2c8>,
#   <matplotlib.axis.XTick at 0x201439cbe88>,
#   <matplotlib.axis.XTick at 0x201439c4e88>,
#   <matplotlib.axis.XTick at 0x201439ce888>,
#   <matplotlib.axis.XTick at 0x201439d2348>,
#   <matplotlib.axis.XTick at 0x201439d2d88>,
#   <matplotlib.axis.XTick at 0x201439d5808>,
#   <matplotlib.axis.XTick at 0x201439d8408>,
#   <matplotlib.axis.XTick at 0x201439d8fc8>,
#   <matplotlib.axis.XTick at 0x201439dcbc8>,
#   <matplotlib.axis.XTick at 0x201439df7c8>,
#   <matplotlib.axis.XTick at 0x201439dc108>,
#   <matplotlib.axis.XTick at 0x201439e22c8>,
#   <matplotlib.axis.XTick at 0x201439e2c48>,
#   <matplotlib.axis.XTick at 0x201439e56c8>,
#   <matplotlib.axis.XTick at 0x201439e9148>,
#   <matplotlib.axis.XTick at 0x201439e9d08>,
#   <matplotlib.axis.XTick at 0x201439ec908>,
#   <matplotlib.axis.XTick at 0x201439f0508>,
#   <matplotlib.axis.XTick at 0x201439f3088>,
#   <matplotlib.axis.XTick at 0x201439ec088>,
#   <matplotlib.axis.XTick at 0x201439f3bc8>,
#   <matplotlib.axis.XTick at 0x201439f6588>,
#   <matplotlib.axis.XTick at 0x201439f6fc8>,
#   <matplotlib.axis.XTick at 0x201439f8a48>,
#   <matplotlib.axis.XTick at 0x201439fb648>,
#   <matplotlib.axis.XTick at 0x201439ff248>,
#   <matplotlib.axis.XTick at 0x201439ffe08>,
#   <matplotlib.axis.XTick at 0x20143a04a08>,
#   <matplotlib.axis.XTick at 0x201439fbb88>,
#   <matplotlib.axis.XTick at 0x20143a07508>,
#   <matplotlib.axis.XTick at 0x20143a07e88>,
#   <matplotlib.axis.XTick at 0x20143a09908>,
#   <matplotlib.axis.XTick at 0x20143a0d388>,
#   <matplotlib.axis.XTick at 0x20143a0df48>,
#   <matplotlib.axis.XTick at 0x20143a11b48>,
#   <matplotlib.axis.XTick at 0x20143a14748>,
#   <matplotlib.axis.XTick at 0x20143a12348>,
#   <matplotlib.axis.XTick at 0x20143a112c8>,
#   <matplotlib.axis.XTick at 0x20143a12e08>,
#   <matplotlib.axis.XTick at 0x20143a1c7c8>,
#   <matplotlib.axis.XTick at 0x20143a1f248>,
#   <matplotlib.axis.XTick at 0x20143a1fc88>,
#   <matplotlib.axis.XTick at 0x20143a21888>,
#   <matplotlib.axis.XTick at 0x20143a26488>,
#   <matplotlib.axis.XTick at 0x20143a29048>,
#   <matplotlib.axis.XTick at 0x20143a29c48>,
#   <matplotlib.axis.XTick at 0x20143a21c48>,
#   <matplotlib.axis.XTick at 0x20143a2d748>,
#   <matplotlib.axis.XTick at 0x20143a2f088>,
#   <matplotlib.axis.XTick at 0x20143a2fb48>,
#   <matplotlib.axis.XTick at 0x20143a325c8>,
#   <matplotlib.axis.XTick at 0x20143a361c8>,
#   <matplotlib.axis.XTick at 0x20143a36d88>,
#   <matplotlib.axis.XTick at 0x20143a3a988>,
#   <matplotlib.axis.XTick at 0x20143a3d588>,
#   <matplotlib.axis.XTick at 0x20143a3aa88>,
#   <matplotlib.axis.XTick at 0x20143a21988>,
#   <matplotlib.axis.XTick at 0x20143a41a08>,
#   <matplotlib.axis.XTick at 0x20143a43488>,
#   <matplotlib.axis.XTick at 0x20143a43ec8>,
#   <matplotlib.axis.XTick at 0x20143a47ac8>,
#   <matplotlib.axis.XTick at 0x20143a4a6c8>,
#   <matplotlib.axis.XTick at 0x20143a4e2c8>,
#   <matplotlib.axis.XTick at 0x20143a4ee88>,
#   <matplotlib.axis.XTick at 0x20143a47e88>,
#   <matplotlib.axis.XTick at 0x20143a51988>,
#   <matplotlib.axis.XTick at 0x20143a53348>,
#   <matplotlib.axis.XTick at 0x20143a53d88>,
#   <matplotlib.axis.XTick at 0x20143a57808>,
#   <matplotlib.axis.XTick at 0x20143a5a408>,
#   <matplotlib.axis.XTick at 0x20143a5afc8>,
#   <matplotlib.axis.XTick at 0x20143a5ebc8>,
#   <matplotlib.axis.XTick at 0x20143a617c8>,
#   <matplotlib.axis.XTick at 0x20143a5e108>,
#   <matplotlib.axis.XTick at 0x20143a632c8>,
#   <matplotlib.axis.XTick at 0x20143a63c48>,
#   <matplotlib.axis.XTick at 0x20143a666c8>,
#   <matplotlib.axis.XTick at 0x20143a6a148>,
#   <matplotlib.axis.XTick at 0x20143a6ad08>,
#   <matplotlib.axis.XTick at 0x20143a6f908>,
#   <matplotlib.axis.XTick at 0x20143a73508>,
#   <matplotlib.axis.XTick at 0x20143a76088>,
#   <matplotlib.axis.XTick at 0x20143a6f088>,
#   <matplotlib.axis.XTick at 0x20143a3dac8>,
#   <matplotlib.axis.XTick at 0x201439ce408>,
#   <matplotlib.axis.XTick at 0x20143a76f88>,
#   <matplotlib.axis.XTick at 0x20143a79a08>,
#   <matplotlib.axis.XTick at 0x20143a7b488>,
#   <matplotlib.axis.XTick at 0x20143a7bec8>,
#   <matplotlib.axis.XTick at 0x20143a7d948>,
#   <matplotlib.axis.XTick at 0x20143a813c8>,
#   <matplotlib.axis.XTick at 0x20143a81e08>,
#   <matplotlib.axis.XTick at 0x20143a79288>,
#   <matplotlib.axis.XTick at 0x20143a855c8>,
#   <matplotlib.axis.XTick at 0x20143a85fc8>,
#   <matplotlib.axis.XTick at 0x20143a89a88>,
#   <matplotlib.axis.XTick at 0x20143a8c508>,
#   <matplotlib.axis.XTick at 0x20143a8f048>,
#   <matplotlib.axis.XTick at 0x20143a8fc88>,
#   <matplotlib.axis.XTick at 0x20143a92888>,
#   <matplotlib.axis.XTick at 0x20143a96488>,
#   <matplotlib.axis.XTick at 0x20143a89bc8>,
#   <matplotlib.axis.XTick at 0x20143a96e08>,
#   <matplotlib.axis.XTick at 0x20143a99888>,
#   <matplotlib.axis.XTick at 0x20143a9b308>,
#   <matplotlib.axis.XTick at 0x20143a9bd48>,
#   <matplotlib.axis.XTick at 0x20143a9f908>,
#   <matplotlib.axis.XTick at 0x20143aa2508>,
#   <matplotlib.axis.XTick at 0x20143aa6088>,
#   <matplotlib.axis.XTick at 0x20143aa6cc8>,
#   <matplotlib.axis.XTick at 0x20143a9fcc8>,
#   <matplotlib.axis.XTick at 0x20143aa96c8>,
#   <matplotlib.axis.XTick at 0x20143aac188>,
#   <matplotlib.axis.XTick at 0x20143aacbc8>,
#   <matplotlib.axis.XTick at 0x20143aae648>,
#   <matplotlib.axis.XTick at 0x20143ab3248>,
#   <matplotlib.axis.XTick at 0x20143ab3e08>,
#   <matplotlib.axis.XTick at 0x20143ab7a08>,
#   <matplotlib.axis.XTick at 0x20143aba608>,
#   <matplotlib.axis.XTick at 0x20143ab7208>,
#   <matplotlib.axis.XTick at 0x20143aa2608>,
#   <matplotlib.axis.XTick at 0x20143ac0a88>,
#   <matplotlib.axis.XTick at 0x20143ac1508>,
#   <matplotlib.axis.XTick at 0x20143ac1f48>,
#   <matplotlib.axis.XTick at 0x20143ac4b48>,
#   <matplotlib.axis.XTick at 0x20143ac8748>,
#   <matplotlib.axis.XTick at 0x20143acb348>,
#   <matplotlib.axis.XTick at 0x20143acbf08>,
#   <matplotlib.axis.XTick at 0x20143ac4f08>,
#   <matplotlib.axis.XTick at 0x20143acfa08>,
#   <matplotlib.axis.XTick at 0x20143ad23c8>,
#   <matplotlib.axis.XTick at 0x20143ad2e08>,
#   <matplotlib.axis.XTick at 0x20143ad4888>,
#   <matplotlib.axis.XTick at 0x20143ad7488>,
#   <matplotlib.axis.XTick at 0x20143adb048>,
#   <matplotlib.axis.XTick at 0x20143adbc48>,
#   <matplotlib.axis.XTick at 0x20143ade848>,
#   <matplotlib.axis.XTick at 0x20143adb188>,
#   <matplotlib.axis.XTick at 0x20143ae3348>,
#   <matplotlib.axis.XTick at 0x20143ae3cc8>,
#   <matplotlib.axis.XTick at 0x20143ae6748>,
#   <matplotlib.axis.XTick at 0x20143ae91c8>,
#   <matplotlib.axis.XTick at 0x20143ae9d88>,
#   <matplotlib.axis.XTick at 0x20143aeb988>,
#   <matplotlib.axis.XTick at 0x20143af0588>,
#   <matplotlib.axis.XTick at 0x20143af3188>,
#   <matplotlib.axis.XTick at 0x20143aeb108>,
#   <matplotlib.axis.XTick at 0x20143af3c48>,
#   <matplotlib.axis.XTick at 0x20143af6608>,
#   <matplotlib.axis.XTick at 0x20143af9048>,
#   <matplotlib.axis.XTick at 0x20143af9ac8>,
#   <matplotlib.axis.XTick at 0x20143afc6c8>,
#   <matplotlib.axis.XTick at 0x20143aff2c8>,
#   <matplotlib.axis.XTick at 0x20143affe88>,
#   <matplotlib.axis.XTick at 0x20143b03a88>,
#   <matplotlib.axis.XTick at 0x20143afca88>,
#   <matplotlib.axis.XTick at 0x20143b06588>,
#   <matplotlib.axis.XTick at 0x20143b06f08>,
#   <matplotlib.axis.XTick at 0x20143b09988>,
#   <matplotlib.axis.XTick at 0x20143b0d408>,
#   <matplotlib.axis.XTick at 0x20143b0dfc8>,
#   <matplotlib.axis.XTick at 0x20143b10bc8>,
#   <matplotlib.axis.XTick at 0x20143b137c8>,
#   <matplotlib.axis.XTick at 0x20143b183c8>,
#   <matplotlib.axis.XTick at 0x20143b10348>,
#   <matplotlib.axis.XTick at 0x20143b18e88>,
#   <matplotlib.axis.XTick at 0x20143b1c848>,
#   <matplotlib.axis.XTick at 0x20143b1f2c8>,
#   <matplotlib.axis.XTick at 0x20143b1fd08>,
#   <matplotlib.axis.XTick at 0x20143b23908>,
#   <matplotlib.axis.XTick at 0x20143b26508>,
#   <matplotlib.axis.XTick at 0x20143b2a088>,
#   <matplotlib.axis.XTick at 0x20143b2acc8>,
#   <matplotlib.axis.XTick at 0x20143b23cc8>,
#   <matplotlib.axis.XTick at 0x20143b2d7c8>,
#   <matplotlib.axis.XTick at 0x20143b2f188>,
#   <matplotlib.axis.XTick at 0x20143b2fbc8>,
#   <matplotlib.axis.XTick at 0x20143b32648>,
#   <matplotlib.axis.XTick at 0x20143b36248>,
#   <matplotlib.axis.XTick at 0x20143b36e08>,
#   <matplotlib.axis.XTick at 0x20143b39a08>,
#   <matplotlib.axis.XTick at 0x20143b3c608>,
#   <matplotlib.axis.XTick at 0x20143b39208>,
#   <matplotlib.axis.XTick at 0x20143b26448>,
#   <matplotlib.axis.XTick at 0x20143b41a88>,
#   <matplotlib.axis.XTick at 0x20143b42508>,
#   <matplotlib.axis.XTick at 0x20143b42f48>,
#   <matplotlib.axis.XTick at 0x20143b47b48>,
#   <matplotlib.axis.XTick at 0x20143b4a748>,
#   <matplotlib.axis.XTick at 0x20143b4e348>,
#   <matplotlib.axis.XTick at 0x20143b4ef08>,
#   <matplotlib.axis.XTick at 0x20143b47f08>,
#   <matplotlib.axis.XTick at 0x20143b2ac08>,
#   <matplotlib.axis.XTick at 0x20143aa90c8>,
#   <matplotlib.axis.XTick at 0x20143b52dc8>,
#   <matplotlib.axis.XTick at 0x20143b53848>,
#   <matplotlib.axis.XTick at 0x20143b542c8>,
#   <matplotlib.axis.XTick at 0x20143b54d08>,
#   <matplotlib.axis.XTick at 0x20143b59788>,
#   <matplotlib.axis.XTick at 0x20143b5c208>,
#   <matplotlib.axis.XTick at 0x20143b5cc48>,
#   <matplotlib.axis.XTick at 0x20143b427c8>,
#   <matplotlib.axis.XTick at 0x20143b60408>,
#   <matplotlib.axis.XTick at 0x20143b60e48>,
#   <matplotlib.axis.XTick at 0x20143b628c8>,
#   <matplotlib.axis.XTick at 0x20143b66348>,
#   <matplotlib.axis.XTick at 0x20143b66ec8>,
#   <matplotlib.axis.XTick at 0x20143b6aac8>,
#   <matplotlib.axis.XTick at 0x20143b6d6c8>,
#   <matplotlib.axis.XTick at 0x20143b6f2c8>,
#   <matplotlib.axis.XTick at 0x20143b62cc8>,
#   <matplotlib.axis.XTick at 0x20143b6fc48>,
#   <matplotlib.axis.XTick at 0x20143b746c8>,
#   <matplotlib.axis.XTick at 0x20143b76148>,
#   <matplotlib.axis.XTick at 0x20143b76b88>,
#   <matplotlib.axis.XTick at 0x20143b79748>,
#   <matplotlib.axis.XTick at 0x20143b7d348>,
#   <matplotlib.axis.XTick at 0x20143b7df08>,
#   <matplotlib.axis.XTick at 0x20143b81b08>,
#   <matplotlib.axis.XTick at 0x20143b79b08>,
#   <matplotlib.axis.XTick at 0x20143b83508>,
#   <matplotlib.axis.XTick at 0x20143b83f88>,
#   <matplotlib.axis.XTick at 0x20143b86a08>,
#   <matplotlib.axis.XTick at 0x20143b8b488>,
#   <matplotlib.axis.XTick at 0x20143b8e048>,
#   <matplotlib.axis.XTick at 0x20143b8ec48>,
#   <matplotlib.axis.XTick at 0x20143b92848>,
#   <matplotlib.axis.XTick at 0x20143b96448>,
#   <matplotlib.axis.XTick at 0x20143b8e3c8>,
#   <matplotlib.axis.XTick at 0x20143b96f08>,
#   <matplotlib.axis.XTick at 0x20143b9a8c8>,
#   <matplotlib.axis.XTick at 0x20143b9c348>,
#   <matplotlib.axis.XTick at 0x20143b9cd88>,
#   <matplotlib.axis.XTick at 0x20143b9f988>,
#   <matplotlib.axis.XTick at 0x20143ba2588>,
#   <matplotlib.axis.XTick at 0x20143ba6188>,
#   <matplotlib.axis.XTick at 0x20143ba6d48>,
#   <matplotlib.axis.XTick at 0x20143b9fd48>,
#   <matplotlib.axis.XTick at 0x20143ba9848>,
#   <matplotlib.axis.XTick at 0x20143bac208>,
#   <matplotlib.axis.XTick at 0x20143bacc48>,
#   <matplotlib.axis.XTick at 0x20143baf6c8>,
#   <matplotlib.axis.XTick at 0x20143bb32c8>,
#   <matplotlib.axis.XTick at 0x20143bb3e88>,
#   <matplotlib.axis.XTick at 0x20143bb6a88>,
#   <matplotlib.axis.XTick at 0x20143bba688>,
#   <matplotlib.axis.XTick at 0x20143bb6048>,
#   <matplotlib.axis.XTick at 0x20143bbe048>,
#   <matplotlib.axis.XTick at 0x20143bbeb08>,
#   <matplotlib.axis.XTick at 0x20143bc0588>,
#   <matplotlib.axis.XTick at 0x20143bc0fc8>,
#   <matplotlib.axis.XTick at 0x20143bc4bc8>,
#   <matplotlib.axis.XTick at 0x20143bc87c8>,
#   <matplotlib.axis.XTick at 0x20143bcb3c8>,
#   <matplotlib.axis.XTick at 0x20143bcbf88>,
#   <matplotlib.axis.XTick at 0x20143bc4f08>,
#   <matplotlib.axis.XTick at 0x20143bcfa88>,
#   <matplotlib.axis.XTick at 0x20143bd2448>,
#   <matplotlib.axis.XTick at 0x20143bd2e88>,
#   <matplotlib.axis.XTick at 0x20143bd4908>,
#   <matplotlib.axis.XTick at 0x20143bd8508>,
#   <matplotlib.axis.XTick at 0x20143bdb088>,
#   <matplotlib.axis.XTick at 0x20143bdbcc8>,
#   <matplotlib.axis.XTick at 0x20143bde8c8>,
#   <matplotlib.axis.XTick at 0x20143bd8e48>,
#   <matplotlib.axis.XTick at 0x20143be23c8>,
#   <matplotlib.axis.XTick at 0x20143be2d48>,
#   <matplotlib.axis.XTick at 0x20143be57c8>,
#   <matplotlib.axis.XTick at 0x20143be8248>,
#   <matplotlib.axis.XTick at 0x20143be8e08>,
#   <matplotlib.axis.XTick at 0x20143beba08>,
#   <matplotlib.axis.XTick at 0x20143bef608>,
#   <matplotlib.axis.XTick at 0x20143bf3208>,
#   <matplotlib.axis.XTick at 0x20143beb188>,
#   <matplotlib.axis.XTick at 0x20143bf3cc8>,
#   <matplotlib.axis.XTick at 0x20143bf7688>,
#   <matplotlib.axis.XTick at 0x20143bf9088>,
#   <matplotlib.axis.XTick at 0x20143bf9b48>,
#   <matplotlib.axis.XTick at 0x20143bfc748>,
#   <matplotlib.axis.XTick at 0x20143c00348>,
#   <matplotlib.axis.XTick at 0x20143c00f08>,
#   <matplotlib.axis.XTick at 0x20143c03b08>,
#   <matplotlib.axis.XTick at 0x20143bfcb08>,
#   <matplotlib.axis.XTick at 0x20143c06608>,
#   <matplotlib.axis.XTick at 0x20143c06f88>,
#   <matplotlib.axis.XTick at 0x20143c09a08>,
#   <matplotlib.axis.XTick at 0x20143c0d488>,
#   <matplotlib.axis.XTick at 0x20143c10048>,
#   <matplotlib.axis.XTick at 0x20143c10c48>,
#   <matplotlib.axis.XTick at 0x20143c13848>,
#   <matplotlib.axis.XTick at 0x20143c19448>,
#   <matplotlib.axis.XTick at 0x20143c103c8>,
#   <matplotlib.axis.XTick at 0x20143c19f08>,
#   <matplotlib.axis.XTick at 0x20143c1c8c8>,
#   <matplotlib.axis.XTick at 0x20143c1e348>,
#   <matplotlib.axis.XTick at 0x20143c1ed88>,
#   <matplotlib.axis.XTick at 0x20143c22988>,
#   <matplotlib.axis.XTick at 0x20143c25588>,
#   <matplotlib.axis.XTick at 0x20143c29188>,
#   <matplotlib.axis.XTick at 0x20143c29d48>,
#   <matplotlib.axis.XTick at 0x20143c22d48>,
#   <matplotlib.axis.XTick at 0x20143c03a48>,
#   <matplotlib.axis.XTick at 0x20143b96988>,
#   <matplotlib.axis.XTick at 0x20143c2dc08>,
#   <matplotlib.axis.XTick at 0x20143c2f688>,
#   <matplotlib.axis.XTick at 0x20143c31088>,
#   <matplotlib.axis.XTick at 0x20143c31b48>,
#   <matplotlib.axis.XTick at 0x20143c345c8>,
#   <matplotlib.axis.XTick at 0x20143c34fc8>,
#   <matplotlib.axis.XTick at 0x20143c39a88>,
#   <matplotlib.axis.XTick at 0x20143bf35c8>,
#   <matplotlib.axis.XTick at 0x20143c3b248>,
#   <matplotlib.axis.XTick at 0x20143c3bc88>,
#   <matplotlib.axis.XTick at 0x20143c3d708>,
#   <matplotlib.axis.XTick at 0x20143c41188>,
#   ...],
#  [Text(0, 0, '0'),
#   Text(1, 0, '5'),
#   Text(2, 0, '10'),
#   Text(3, 0, '15'),
#   Text(4, 0, '20'),
#   Text(5, 0, '25'),
#   Text(6, 0, '30'),
#   Text(7, 0, '35'),
#   Text(8, 0, '40'),
#   Text(9, 0, '45'),
#   Text(10, 0, '0'),
#   Text(11, 0, '5'),
#   Text(12, 0, '10'),
#   Text(13, 0, '15'),
#   Text(14, 0, '20'),
#   Text(15, 0, '25'),
#   Text(16, 0, '30'),
#   Text(17, 0, '35'),
#   Text(18, 0, '40'),
#   Text(19, 0, '45'),
#   Text(20, 0, '0'),
#   Text(21, 0, '5'),
#   Text(22, 0, '10'),
#   Text(23, 0, '15'),
#   Text(24, 0, '20'),
#   Text(25, 0, '25'),
#   Text(26, 0, '30'),
#   Text(27, 0, '35'),
#   Text(28, 0, '40'),
#   Text(29, 0, '45'),
#   Text(30, 0, '0'),
#   Text(31, 0, '5'),
#   Text(32, 0, '10'),
#   Text(33, 0, '15'),
#   Text(34, 0, '20'),
#   Text(35, 0, '25'),
#   Text(36, 0, '30'),
#   Text(37, 0, '35'),
#   Text(38, 0, '40'),
#   Text(39, 0, '45'),
#   Text(40, 0, '0'),
#   Text(41, 0, '5'),
#   Text(42, 0, '10'),
#   Text(43, 0, '15'),
#   Text(44, 0, '20'),
#   Text(45, 0, '25'),
#   Text(46, 0, '30'),
#   Text(47, 0, '35'),
#   Text(48, 0, '40'),
#   Text(49, 0, '45'),
#   Text(50, 0, '0'),
#   Text(51, 0, '5'),
#   Text(52, 0, '10'),
#   Text(53, 0, '15'),
#   Text(54, 0, '20'),
#   Text(55, 0, '25'),
#   Text(56, 0, '30'),
#   Text(57, 0, '35'),
#   Text(58, 0, '40'),
#   Text(59, 0, '45'),
#   Text(60, 0, '0'),
#   Text(61, 0, '5'),
#   Text(62, 0, '10'),
#   Text(63, 0, '15'),
#   Text(64, 0, '20'),
#   Text(65, 0, '0'),
#   Text(66, 0, '5'),
#   Text(67, 0, '10'),
#   Text(68, 0, '15'),
#   Text(69, 0, '20'),
#   Text(70, 0, '25'),
#   Text(71, 0, '30'),
#   Text(72, 0, '35'),
#   Text(73, 0, '40'),
#   Text(74, 0, '45'),
#   Text(75, 0, '0'),
#   Text(76, 0, '5'),
#   Text(77, 0, '10'),
#   Text(78, 0, '15'),
#   Text(79, 0, '20'),
#   Text(80, 0, '25'),
#   Text(81, 0, '30'),
#   Text(82, 0, '35'),
#   Text(83, 0, '40'),
#   Text(84, 0, '45'),
#   Text(85, 0, '0'),
#   Text(86, 0, '5'),
#   Text(87, 0, '10'),
#   Text(88, 0, '15'),
#   Text(89, 0, '20'),
#   Text(90, 0, '25'),
#   Text(91, 0, '30'),
#   Text(92, 0, '35'),
#   Text(93, 0, '40'),
#   Text(94, 0, '45'),
#   Text(95, 0, '0'),
#   Text(96, 0, '5'),
#   Text(97, 0, '10'),
#   Text(98, 0, '15'),
#   Text(99, 0, '20'),
#   Text(100, 0, '25'),
#   Text(101, 0, '30'),
#   Text(102, 0, '35'),
#   Text(103, 0, '40'),
#   Text(104, 0, '45'),
#   Text(105, 0, '0'),
#   Text(106, 0, '5'),
#   Text(107, 0, '10'),
#   Text(108, 0, '15'),
#   Text(109, 0, '20'),
#   Text(110, 0, '25'),
#   Text(111, 0, '30'),
#   Text(112, 0, '35'),
#   Text(113, 0, '40'),
#   Text(114, 0, '45'),
#   Text(115, 0, '0'),
#   Text(116, 0, '5'),
#   Text(117, 0, '10'),
#   Text(118, 0, '15'),
#   Text(119, 0, '20'),
#   Text(120, 0, '25'),
#   Text(121, 0, '30'),
#   Text(122, 0, '35'),
#   Text(123, 0, '40'),
#   Text(124, 0, '45'),
#   Text(125, 0, '0'),
#   Text(126, 0, '5'),
#   Text(127, 0, '10'),
#   Text(128, 0, '15'),
#   Text(129, 0, '20'),
#   Text(130, 0, '25'),
#   Text(131, 0, '30'),
#   Text(132, 0, '35'),
#   Text(133, 0, '40'),
#   Text(134, 0, '45'),
#   Text(135, 0, '0'),
#   Text(136, 0, '5'),
#   Text(137, 0, '10'),
#   Text(138, 0, '15'),
#   Text(139, 0, '20'),
#   Text(140, 0, '25'),
#   Text(141, 0, '30'),
#   Text(142, 0, '35'),
#   Text(143, 0, '40'),
#   Text(144, 0, '45'),
#   Text(145, 0, '0'),
#   Text(146, 0, '5'),
#   Text(147, 0, '10'),
#   Text(148, 0, '15'),
#   Text(149, 0, '20'),
#   Text(150, 0, '25'),
#   Text(151, 0, '30'),
#   Text(152, 0, '35'),
#   Text(153, 0, '40'),
#   Text(154, 0, '45'),
#   Text(155, 0, '0'),
#   Text(156, 0, '5'),
#   Text(157, 0, '10'),
#   Text(158, 0, '15'),
#   Text(159, 0, '20'),
#   Text(160, 0, '25'),
#   Text(161, 0, '30'),
#   Text(162, 0, '35'),
#   Text(163, 0, '40'),
#   Text(164, 0, '45'),
#   Text(165, 0, '0'),
#   Text(166, 0, '5'),
#   Text(167, 0, '10'),
#   Text(168, 0, '15'),
#   Text(169, 0, '20'),
#   Text(170, 0, '25'),
#   Text(171, 0, '30'),
#   Text(172, 0, '35'),
#   Text(173, 0, '40'),
#   Text(174, 0, '45'),
#   Text(175, 0, '0'),
#   Text(176, 0, '5'),
#   Text(177, 0, '10'),
#   Text(178, 0, '15'),
#   Text(179, 0, '20'),
#   Text(180, 0, '25'),
#   Text(181, 0, '30'),
#   Text(182, 0, '35'),
#   Text(183, 0, '40'),
#   Text(184, 0, '45'),
#   Text(185, 0, '0'),
#   Text(186, 0, '5'),
#   Text(187, 0, '10'),
# ...
#   Text(265, 0, '10'),
#   Text(266, 0, '15'),
#   Text(267, 0, '20'),
#   Text(268, 0, '25'),
#   Text(269, 0, '30'),
#   Text(270, 0, '35'),
#   Text(271, 0, '40'),
#   Text(272, 0, '45'),
#   Text(273, 0, '0'),
#   Text(274, 0, '5'),
#   Text(275, 0, '10'),
#   Text(276, 0, '15'),
#   Text(277, 0, '20'),
#   Text(278, 0, '25'),
#   Text(279, 0, '30'),
#   Text(280, 0, '35'),
#   Text(281, 0, '40'),
#   Text(282, 0, '45'),
#   Text(283, 0, '0'),
#   Text(284, 0, '5'),
#   Text(285, 0, '10'),
#   Text(286, 0, '15'),
#   Text(287, 0, '20'),
#   Text(288, 0, '25'),
#   Text(289, 0, '30'),
#   Text(290, 0, '0'),
#   Text(291, 0, '5'),
#   Text(292, 0, '10'),
#   Text(293, 0, '15'),
#   Text(294, 0, '20'),
#   Text(295, 0, '25'),
#   Text(296, 0, '30'),
#   Text(297, 0, '35'),
#   Text(298, 0, '40'),
#   Text(299, 0, '45'),
#   Text(300, 0, '0'),
#   Text(301, 0, '5'),
#   Text(302, 0, '10'),
#   Text(303, 0, '15'),
#   Text(304, 0, '20'),
#   Text(305, 0, '25'),
#   Text(306, 0, '30'),
#   Text(307, 0, '35'),
#   Text(308, 0, '40'),
#   Text(309, 0, '45'),
#   Text(310, 0, '0'),
#   Text(311, 0, '5'),
#   Text(312, 0, '10'),
#   Text(313, 0, '15'),
#   Text(314, 0, '20'),
#   Text(315, 0, '25'),
#   Text(316, 0, '30'),
#   Text(317, 0, '35'),
#   Text(318, 0, '0'),
#   Text(319, 0, '5'),
#   Text(320, 0, '10'),
#   Text(321, 0, '15'),
#   Text(322, 0, '20'),
#   Text(323, 0, '25'),
#   Text(324, 0, '30'),
#   Text(325, 0, '35'),
#   Text(326, 0, '40'),
#   Text(327, 0, '45'),
#   Text(328, 0, '0'),
#   Text(329, 0, '5'),
#   Text(330, 0, '10'),
#   Text(331, 0, '15'),
#   Text(332, 0, '20'),
#   Text(333, 0, '25'),
#   Text(334, 0, '30'),
#   Text(335, 0, '35'),
#   Text(336, 0, '40'),
#   Text(337, 0, '45'),
#   Text(338, 0, '0'),
#   Text(339, 0, '5'),
#   Text(340, 0, '10'),
#   Text(341, 0, '0'),
#   Text(342, 0, '5'),
#   Text(343, 0, '10'),
#   Text(344, 0, '15'),
#   Text(345, 0, '20'),
#   Text(346, 0, '25'),
#   Text(347, 0, '30'),
#   Text(348, 0, '35'),
#   Text(349, 0, '40'),
#   Text(350, 0, '45'),
#   Text(351, 0, '0'),
#   Text(352, 0, '5'),
#   Text(353, 0, '10'),
#   Text(354, 0, '15'),
#   Text(355, 0, '20'),
#   Text(356, 0, '25'),
#   Text(357, 0, '30'),
#   Text(358, 0, '35'),
#   Text(359, 0, '40'),
#   Text(360, 0, '45'),
#   Text(361, 0, '0'),
#   Text(362, 0, '5'),
#   Text(363, 0, '10'),
#   Text(364, 0, '15'),
#   Text(365, 0, '20'),
#   Text(366, 0, '25'),
#   Text(367, 0, '30'),
#   Text(368, 0, '35'),
#   Text(369, 0, '40'),
#   Text(370, 0, '45'),
#   Text(371, 0, '0'),
#   Text(372, 0, '5'),
#   Text(373, 0, '10'),
#   Text(374, 0, '15'),
#   Text(375, 0, '20'),
#   Text(376, 0, '25'),
#   Text(377, 0, '30'),
#   Text(378, 0, '35'),
#   Text(379, 0, '40'),
#   Text(380, 0, '45'),
#   Text(381, 0, '0'),
#   Text(382, 0, '5'),
#   Text(383, 0, '10'),
#   Text(384, 0, '15'),
#   Text(385, 0, '20'),
#   Text(386, 0, '25'),
#   Text(387, 0, '30'),
#   Text(388, 0, '35'),
#   Text(389, 0, '40'),
#   Text(390, 0, '45'),
#   Text(391, 0, '0'),
#   Text(392, 0, '5'),
#   Text(393, 0, '10'),
#   Text(394, 0, '15'),
#   Text(395, 0, '20'),
#   Text(396, 0, '25'),
#   Text(397, 0, '30'),
#   Text(398, 0, '35'),
#   Text(399, 0, '40'),
#   Text(400, 0, '45'),
#   Text(401, 0, '0'),
#   Text(402, 0, '5'),
#   Text(403, 0, '10'),
#   Text(404, 0, '15'),
#   Text(405, 0, '20'),
#   Text(406, 0, '25'),
#   Text(407, 0, '30'),
#   Text(408, 0, '35'),
#   Text(409, 0, '40'),
#   Text(410, 0, '45'),
#   Text(411, 0, '0'),
#   Text(412, 0, '5'),
#   Text(413, 0, '10'),
#   Text(414, 0, '15'),
#   Text(415, 0, '20'),
#   Text(416, 0, '25'),
#   Text(417, 0, '30'),
#   Text(418, 0, '35'),
#   Text(419, 0, '40'),
#   Text(420, 0, '45'),
#   Text(421, 0, '0'),
#   Text(422, 0, '5'),
#   Text(423, 0, '10'),
#   Text(424, 0, '15'),
#   Text(425, 0, '20'),
#   Text(426, 0, '25'),
#   Text(427, 0, '30'),
#   Text(428, 0, '35'),
#   Text(429, 0, '40'),
#   Text(430, 0, '45'),
#   Text(431, 0, '0'),
#   Text(432, 0, '5'),
#   Text(433, 0, '10'),
#   Text(434, 0, '15'),
#   Text(435, 0, '20'),
#   Text(436, 0, '25'),
#   Text(437, 0, '30'),
#   Text(438, 0, '35'),
#   Text(439, 0, '40'),
#   Text(440, 0, '45'),
#   Text(441, 0, '0'),
#   Text(442, 0, '5'),
#   Text(443, 0, '10'),
#   Text(444, 0, '15'),
#   Text(445, 0, '20'),
#   Text(446, 0, '25'),
#   Text(447, 0, '30'),
#   Text(448, 0, '0'),
#   Text(449, 0, '5'),
#   Text(450, 0, '0'),
#   Text(451, 0, '5'),
#   Text(452, 0, '10'),
#   Text(453, 0, '15'),
#   Text(454, 0, '0'),
#   Text(455, 0, '5'),
#   Text(456, 0, '10'),
#   Text(457, 0, '15'),
#   Text(458, 0, '20'),
#   Text(459, 0, '25'),
#   Text(460, 0, '30'),
#   Text(461, 0, '35'),
#   Text(462, 0, '40'),
#   Text(463, 0, '45'),
#   Text(464, 0, '0'),
#   Text(465, 0, '5'),
#   Text(466, 0, '10'),
#   Text(467, 0, '15'),
#   Text(468, 0, '20'),
#   Text(469, 0, '25'),
#   Text(470, 0, '30'),
#   Text(471, 0, '35'),
#   Text(472, 0, '40'),
#   Text(473, 0, '45'),
#   Text(474, 0, '0'),
#   Text(475, 0, '5'),
#   Text(476, 0, '10'),
#   Text(477, 0, '15'),
#   Text(478, 0, '20'),
#   Text(479, 0, '25'),
#   Text(480, 0, '30'),
#   Text(481, 0, '35'),
#   Text(482, 0, '40'),
#   Text(483, 0, '45'),
#   Text(484, 0, '0'),
#   Text(485, 0, '5'),
#   Text(486, 0, '10'),
#   Text(487, 0, '15'),
#   Text(488, 0, '20'),
#   Text(489, 0, '25'),
#   Text(490, 0, '30'),
#   Text(491, 0, '35'),
#   Text(492, 0, '40'),
#   Text(493, 0, '45'),
#   Text(494, 0, '0'),
#   Text(495, 0, '5'),
#   Text(496, 0, '10'),
#   Text(497, 0, '15'),
#   Text(498, 0, '20'),
#   Text(499, 0, '25'),
#   Text(500, 0, '30'),
#   Text(501, 0, '0'),
#   Text(502, 0, '5'),
#   Text(503, 0, '10'),
#   Text(504, 0, '15'),
#   Text(505, 0, '20'),
#   Text(506, 0, '25'),
#   Text(507, 0, '30'),
#   Text(508, 0, '35'),
#   Text(509, 0, '40'),
#   Text(510, 0, '45'),
#   Text(511, 0, '0'),
#   Text(512, 0, '5'),
#   Text(513, 0, '10'),
#   Text(514, 0, '0'),
#   Text(515, 0, '5'),
#   Text(516, 0, '10'),
#   Text(517, 0, '15'),
#   Text(518, 0, '20'),
#   Text(519, 0, '25'),
#   Text(520, 0, '30'),
#   Text(521, 0, '35'),
#   Text(522, 0, '40'),
#   Text(523, 0, '45'),
#   Text(524, 0, '0'),
#   Text(525, 0, '5'),
#   Text(526, 0, '10'),
#   Text(527, 0, '15'),
#   Text(528, 0, '20'),
#   Text(529, 0, '25'),
#   Text(530, 0, '30'),
#   Text(531, 0, '0'),
#   Text(532, 0, '5'),
#   Text(533, 0, '10'),
#   Text(534, 0, '15'),
#   Text(535, 0, '20'),
#   Text(536, 0, '25'),
#   Text(537, 0, '30'),
#   Text(538, 0, '35'),
#   Text(539, 0, '40'),
#   Text(540, 0, '45'),
#   Text(541, 0, '0'),
#   Text(542, 0, '5'),
#   Text(543, 0, '10'),
#   Text(544, 0, '15'),
#   Text(545, 0, '20'),
#   Text(546, 0, '25'),
#   Text(547, 0, '30'),
#   Text(548, 0, '35'),
#   Text(549, 0, '40'),
#   Text(550, 0, '45'),
#   Text(551, 0, '0'),
#   Text(552, 0, '5'),
#   Text(553, 0, '10'),
#   Text(554, 0, '15'),
#   Text(555, 0, '20'),
#   Text(556, 0, '25'),
#   Text(557, 0, '30'),
#   Text(558, 0, '0'),
#   Text(559, 0, '5'),
#   Text(560, 0, '10'),
#   Text(561, 0, '15'),
#   Text(562, 0, '20'),
#   Text(563, 0, '25'),
#   Text(564, 0, '30'),
#   Text(565, 0, '35'),
#   Text(566, 0, '40'),
#   Text(567, 0, '45'),
#   Text(568, 0, '0'),
#   Text(569, 0, '5'),
#   Text(570, 0, '10'),
#   Text(571, 0, '15'),
#   Text(572, 0, '20'),
#   Text(573, 0, '25'),
#   Text(574, 0, '30'),
#   Text(575, 0, '35'),
#   Text(576, 0, '40'),
#   Text(577, 0, '45'),
#   Text(578, 0, '0'),
#   Text(579, 0, '5'),
#   Text(580, 0, '10'),
#   Text(581, 0, '15'),
#   Text(582, 0, '20'),
#   Text(583, 0, '25'),
#   Text(584, 0, '30'),
#   Text(585, 0, '35'),
#   Text(586, 0, '40'),
#   Text(587, 0, '45'),
#   Text(588, 0, '0'),
#   Text(589, 0, '5'),
#   Text(590, 0, '10'),
#   Text(591, 0, '15'),
#   Text(592, 0, '20'),
#   Text(593, 0, '25'),
#   Text(594, 0, '0'),
#   Text(595, 0, '0'),
#   Text(596, 0, '5'),
#   Text(597, 0, '10'),
#   Text(598, 0, '15'),
#   Text(599, 0, '20'),
#   Text(600, 0, '25'),
#   Text(601, 0, '0'),
#   Text(602, 0, '5'),
#   Text(603, 0, '10'),
#   Text(604, 0, '15'),
#   Text(605, 0, '20'),
#   Text(606, 0, '25'),
#   Text(607, 0, '30'),
#   Text(608, 0, '35'),
#   Text(609, 0, '40'),
#   Text(610, 0, '45'),
#   Text(611, 0, '0'),
#   Text(612, 0, '5'),
#   Text(613, 0, '10'),
#   Text(614, 0, '15'),
#   Text(615, 0, '20'),
#   Text(616, 0, '25'),
#   Text(617, 0, '30'),
#   Text(618, 0, '0'),
#   Text(619, 0, '5'),
#   Text(620, 0, '10'),
#   Text(621, 0, '15'),
#   Text(622, 0, '20'),
#   Text(623, 0, '25'),
#   Text(624, 0, '30'),
#   Text(625, 0, '35'),
#   Text(626, 0, '40'),
#   Text(627, 0, '45'),
#   Text(628, 0, '0'),
#   Text(629, 0, '5'),
#   Text(630, 0, '10'),
#   Text(631, 0, '15'),
#   Text(632, 0, '20'),
#   Text(633, 0, '25'),
#   Text(634, 0, '30'),
#   Text(635, 0, '35'),
#   Text(636, 0, '40'),
#   Text(637, 0, '45'),
#   Text(638, 0, '0'),
#   Text(639, 0, '5'),
#   Text(640, 0, '10'),
#   Text(641, 0, '15'),
#   Text(642, 0, '20'),
#   Text(643, 0, '25'),
#   Text(644, 0, '30'),
#   Text(645, 0, '35'),
#   Text(646, 0, '40'),
#   Text(647, 0, '45'),
#   Text(648, 0, '0'),
#   Text(649, 0, '5'),
#   Text(650, 0, '10'),
#   Text(651, 0, '15'),
#   Text(652, 0, '20'),
#   Text(653, 0, '25'),
#   Text(654, 0, '30'),
#   Text(655, 0, '35'),
#   Text(656, 0, '40'),
#   Text(657, 0, '45'),
#   Text(658, 0, '0'),
#   Text(659, 0, '5'),
#   Text(660, 0, '10'),
#   Text(661, 0, '15'),
#   Text(662, 0, '20'),
#   Text(663, 0, '25'),
#   Text(664, 0, '30'),
#   Text(665, 0, '35'),
#   Text(666, 0, '40'),
#   Text(667, 0, '45'),
#   Text(668, 0, '0'),
#   Text(669, 0, '5'),
#   Text(670, 0, '0'),
#   Text(671, 0, '5'),
#   Text(672, 0, '10'),
#   Text(673, 0, '15'),
#   Text(674, 0, '20'),
#   Text(675, 0, '25'),
#   Text(676, 0, '30'),
#   Text(677, 0, '35'),
#   Text(678, 0, '40'),
#   Text(679, 0, '45'),
#   Text(680, 0, '0'),
#   Text(681, 0, '5'),
#   Text(682, 0, '10'),
#   Text(683, 0, '15'),
#   Text(684, 0, '20'),
#   Text(685, 0, '25'),
#   Text(686, 0, '30'),
#   Text(687, 0, '35'),
#   Text(688, 0, '40'),
#   Text(689, 0, '45'),
#   Text(690, 0, '0'),
#   Text(691, 0, '5'),
#   Text(692, 0, '10'),
#   Text(693, 0, '15'),
#   Text(694, 0, '20'),
#   Text(695, 0, '25'),
#   Text(696, 0, '30'),
#   Text(697, 0, '0'),
#   Text(698, 0, '5'),
#   Text(699, 0, '10'),
#   Text(700, 0, '15'),
#   Text(701, 0, '20'),
#   Text(702, 0, '25'),
#   Text(703, 0, '30'),
#   Text(704, 0, '35'),
#   Text(705, 0, '40'),
#   Text(706, 0, '45'),
#   Text(707, 0, '0'),
#   Text(708, 0, '5'),
#   Text(709, 0, '10'),
#   Text(710, 0, '15'),
#   Text(711, 0, '20'),
#   Text(712, 0, '25'),
#   Text(713, 0, '30'),
#   Text(714, 0, '35'),
#   Text(715, 0, '40'),
#   Text(716, 0, '45'),
#   Text(717, 0, '0'),
#   Text(718, 0, '5'),
#   Text(719, 0, '10'),
#   Text(720, 0, '15'),
#   Text(721, 0, '20'),
#   Text(722, 0, '25'),
#   Text(723, 0, '30'),
#   Text(724, 0, '35'),
#   Text(725, 0, '40'),
#   Text(726, 0, '0'),
#   Text(727, 0, '5'),
#   Text(728, 0, '10'),
#   Text(729, 0, '15'),
#   Text(730, 0, '20'),
#   Text(731, 0, '25'),
#   Text(732, 0, '30'),
#   Text(733, 0, '35'),
#   Text(734, 0, '40'),
#   Text(735, 0, '45'),
#   Text(736, 0, '0'),
#   Text(737, 0, '5'),
#   Text(738, 0, '10'),
#   Text(739, 0, '15'),
#   Text(740, 0, '20'),
#   Text(741, 0, '25'),
#   Text(742, 0, '30'),
#   Text(743, 0, '0'),
#   Text(744, 0, '5'),
#   Text(745, 0, '10'),
#   Text(746, 0, '15'),
#   Text(747, 0, '20'),
#   Text(748, 0, '25'),
#   Text(749, 0, '30'),
#   Text(750, 0, '35'),
#   Text(751, 0, '40'),
#   Text(752, 0, '0'),
#   Text(753, 0, '0'),
#   Text(754, 0, '5'),
#   Text(755, 0, '10'),
#   Text(756, 0, '0'),
#   Text(757, 0, '5'),
#   Text(758, 0, '10'),
#   Text(759, 0, '15'),
#   Text(760, 0, '20'),
#   Text(761, 0, '25'),
#   Text(762, 0, '30'),
#   Text(763, 0, '35'),
#   Text(764, 0, '40'),
#   Text(765, 0, '0'),
#   Text(766, 0, '5'),
#   Text(767, 0, '10'),
#   Text(768, 0, '15'),
#   Text(769, 0, '20'),
#   Text(770, 0, '25'),
#   Text(771, 0, '30'),
#   Text(772, 0, '35'),
#   Text(773, 0, '40'),
#   Text(774, 0, '45'),
#   Text(775, 0, '0'),
#   Text(776, 0, '5'),
#   Text(777, 0, '10'),
#   Text(778, 0, '15'),
#   Text(779, 0, '20'),
#   Text(780, 0, '25'),
#   Text(781, 0, '30'),
#   Text(782, 0, '35'),
#   Text(783, 0, '40'),
#   Text(784, 0, '45'),
#   Text(785, 0, '0'),
#   Text(786, 0, '5'),
#   Text(787, 0, '10'),
#   Text(788, 0, '15'),
#   Text(789, 0, '20'),
#   Text(790, 0, '25'),
#   Text(791, 0, '0'),
#   Text(792, 0, '5'),
#   Text(793, 0, '10'),
#   Text(794, 0, '15'),
#   Text(795, 0, '20'),
#   Text(796, 0, '25'),
#   Text(797, 0, '30'),
#   Text(798, 0, '35'),
#   Text(799, 0, '40'),
#   Text(800, 0, '45'),
#   Text(801, 0, '0'),
#   Text(802, 0, '5'),
#   Text(803, 0, '10'),
#   Text(804, 0, '15'),
#   Text(805, 0, '20'),
#   Text(806, 0, '25'),
#   Text(807, 0, '30'),
#   Text(808, 0, '35'),
#   Text(809, 0, '40'),
#   Text(810, 0, '45'),
#   Text(811, 0, '0'),
#   Text(812, 0, '5'),
#   Text(813, 0, '10'),
#   Text(814, 0, '15'),
#   Text(815, 0, '0'),
#   Text(816, 0, '5'),
#   Text(817, 0, '10'),
#   Text(818, 0, '15'),
#   Text(819, 0, '20'),
#   Text(820, 0, '25'),
#   Text(821, 0, '30'),
#   Text(822, 0, '35'),
#   Text(823, 0, '0'),
#   Text(824, 0, '5'),
#   Text(825, 0, '0'),
#   Text(826, 0, '5'),
#   Text(827, 0, '10'),
#   Text(828, 0, '15'),
#   Text(829, 0, '20'),
#   Text(830, 0, '25'),
#   Text(831, 0, '30'),
#   Text(832, 0, '35'),
#   Text(833, 0, '40'),
#   Text(834, 0, '45'),
#   Text(835, 0, '0'),
#   Text(836, 0, '5'),
#   Text(837, 0, '0'),
#   Text(838, 0, '5'),
#   Text(839, 0, '10'),
#   Text(840, 0, '15'),
#   Text(841, 0, '0'),
#   Text(842, 0, '5'),
#   Text(843, 0, '10'),
#   Text(844, 0, '15'),
#   Text(845, 0, '20'),
#   Text(846, 0, '25'),
#   Text(847, 0, '30'),
#   Text(848, 0, '35'),
#   Text(849, 0, '40'),
#   Text(850, 0, '45'),
#   Text(851, 0, '0'),
#   Text(852, 0, '0'),
#   Text(853, 0, '5'),
#   Text(854, 0, '10'),
#   Text(855, 0, '15'),
#   Text(856, 0, '20'),
#   Text(857, 0, '0'),
#   Text(858, 0, '5'),
#   Text(859, 0, '10'),
#   Text(860, 0, '15'),
#   Text(861, 0, '20'),
#   Text(862, 0, '25'),
#   Text(863, 0, '30'),
#   Text(864, 0, '35'),
#   Text(865, 0, '0'),
#   Text(866, 0, '5'),
#   Text(867, 0, '10'),
#   Text(868, 0, '15'),
#   Text(869, 0, '20'),
#   Text(870, 0, '25'),
#   Text(871, 0, '30'),
#   Text(872, 0, '35'),
#   Text(873, 0, '40'),
#   Text(874, 0, '45'),
#   Text(875, 0, '0'),
#   Text(876, 0, '5'),
#   Text(877, 0, '10'),
#   Text(878, 0, '15'),
#   Text(879, 0, '20'),
#   Text(880, 0, '25'),
#   Text(881, 0, '30'),
#   Text(882, 0, '35'),
#   Text(883, 0, '40'),
#   Text(884, 0, '45'),
#   Text(885, 0, '0'),
#   Text(886, 0, '5'),
#   Text(887, 0, '10'),
#   Text(888, 0, '15'),
#   Text(889, 0, '20'),
#   Text(890, 0, '25'),
#   Text(891, 0, '30'),
#   Text(892, 0, '35'),
#   Text(893, 0, '40'),
#   Text(894, 0, '0'),
#   Text(895, 0, '5'),
#   Text(896, 0, '10'),
#   Text(897, 0, '15'),
#   Text(898, 0, '20'),
#   Text(899, 0, '25'),
#   Text(900, 0, '30'),
#   Text(901, 0, '35'),
#   Text(902, 0, '40'),
#   Text(903, 0, '45'),
#   Text(904, 0, '0'),
#   Text(905, 0, '5'),
#   Text(906, 0, '10'),
#   Text(907, 0, '15'),
#   Text(908, 0, '0'),
#   Text(909, 0, '5'),
#   Text(910, 0, '10'),
#   Text(911, 0, '15'),
#   Text(912, 0, '20'),
#   Text(913, 0, '25'),
#   Text(914, 0, '30'),
#   Text(915, 0, '35'),
#   Text(916, 0, '40'),
#   Text(917, 0, '45'),
#   Text(918, 0, '0'),
#   Text(919, 0, '5'),
#   Text(920, 0, '10'),
#   Text(921, 0, '15'),
#   Text(922, 0, '20'),
#   Text(923, 0, '25'),
#   Text(924, 0, '30'),
#   Text(925, 0, '0'),
#   Text(926, 0, '0'),
#   Text(927, 0, '5'),
#   Text(928, 0, '0'),
#   Text(929, 0, '5'),
#   Text(930, 0, '10'),
#   Text(931, 0, '15'),
#   Text(932, 0, '20'),
#   Text(933, 0, '25'),
#   Text(934, 0, '30'),
#   Text(935, 0, '35'),
#   Text(936, 0, '40'),
#   Text(937, 0, '0'),
#   Text(938, 0, '5'),
#   Text(939, 0, '10'),
#   Text(940, 0, '0'),
#   Text(941, 0, '5'),
#   Text(942, 0, '10'),
#   Text(943, 0, '15'),
#   Text(944, 0, '20'),
#   Text(945, 0, '25'),
#   Text(946, 0, '30'),
#   Text(947, 0, '35'),
#   Text(948, 0, '40'),
#   Text(949, 0, '45'),
#   Text(950, 0, '0'),
#   Text(951, 0, '5'),
#   Text(952, 0, '10'),
#   Text(953, 0, '15'),
#   Text(954, 0, '20'),
#   Text(955, 0, '25'),
#   Text(956, 0, '0'),
#   Text(957, 0, '5'),
#   Text(958, 0, '10'),
#   Text(959, 0, '15'),
#   Text(960, 0, '20'),
#   Text(961, 0, '25'),
#   Text(962, 0, '30'),
#   Text(963, 0, '35'),
#   Text(964, 0, '40'),
#   Text(965, 0, '45'),
#   Text(966, 0, '0'),
#   Text(967, 0, '5'),
#   Text(968, 0, '10'),
#   Text(969, 0, '15'),
#   Text(970, 0, '20'),
#   Text(971, 0, '0'),
#   Text(972, 0, '5'),
#   Text(973, 0, '10'),
#   Text(974, 0, '15'),
#   Text(975, 0, '20'),
#   Text(976, 0, '25'),
#   Text(977, 0, '30'),
#   Text(978, 0, '35'),
#   Text(979, 0, '40'),
#   Text(980, 0, '45'),
#   Text(981, 0, '0'),
#   Text(982, 0, '5'),
#   Text(983, 0, '10'),
#   Text(984, 0, '15'),
#   Text(985, 0, '20'),
#   Text(986, 0, '25'),
#   Text(987, 0, '30'),
#   Text(988, 0, '35'),
#   Text(989, 0, '40'),
#   Text(990, 0, '45'),
#   Text(991, 0, '0'),
#   Text(992, 0, '5'),
#   Text(993, 0, '10'),
#   Text(994, 0, '15'),
#   Text(995, 0, '20'),
#   Text(996, 0, '25'),
#   Text(997, 0, '30'),
#   Text(998, 0, '35'),
#   Text(999, 0, '40'),
#   ...])

# %%
# Generate a bar plot showing the total number of measurements taken on each drug regimen using pyplot.
# Set a Title and labels
plt.title("Total Number of Measurements per Drug Regimen")
plt.xlabel("Drug Regimen")
plt.ylabel("Number of Timepoints")
# Out:
# Text(0, 0.5, 'Number of Timepoints')

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas
# Labels for the sections of our pie chart

labels = ["Male", "Female"]

# The values of each section of the pie chart
sizes = [50, 50]

# The colors of each section of the pie chart
colors = ["red", "lightskyblue"]
plt.pie(sizes, labels=labels, colors=colors,
        autopct="%1.1f%%", shadow=False, startangle=140)
# Out:
# ([<matplotlib.patches.Wedge at 0x20145d0d448>,
#   <matplotlib.patches.Wedge at 0x20145d0f608>],
#  [Text(-0.7070663706551935, -0.8426488874308757, 'Male'),
#   Text(0.7070663706551936, 0.8426488874308756, 'Female')],
#  [Text(-0.38567256581192366, -0.45962666587138673, '50.0%'),
#   Text(0.3856725658119237, 0.4596266658713867, '50.0%')])

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
len(clean_df("sex"))

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse


# Merge this group df with the original dataframe to get the tumor volume at the last timepoint

# %%
# Put treatments into a list for for loop (and later for plot labels)


# Create empty list to fill with tumor vol data (for plotting)


# Calculate the IQR and quantitatively determine if there are any potential outliers. 

    
    # Locate the rows which contain mice on each drug and get the tumor volumes
    
    
    # add subset 
    
    
    # Determine outliers using upper and lower bounds

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
